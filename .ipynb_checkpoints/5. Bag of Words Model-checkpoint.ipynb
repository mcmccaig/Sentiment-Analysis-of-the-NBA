# %% [markdown]
# # Bag of Words Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import re
import datetime

import statsmodels.api as sm

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.naive_bayes import MultinomialNB

from xgboost import XGBClassifier

from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

pd.set_option('max_colwidth', 1000)

# %%
#combine all txt files into one dataframe
all_files = glob.glob("data/SemEval Tweets/*.txt")
column_names = ['ID', 'Sentiment', 'Tweet']
list = []

for filename in all_files:
    df = pd.read_csv(filename, sep='\t', names=column_names, index_col=False, encoding='utf-8')
    list.append(df)

training_data = pd.concat(list, axis=0, ignore_index=True)

# %%
training_data
# Out:
#                        ID Sentiment  \
# 0      260097528899452929   neutral
# 1      263791921753882624   neutral
# 2      264194578381410304  negative
# 3      264041328420204544   neutral
# 4      263816256640126976   neutral
# ...                   ...       ...
# 50078  639855845958885376  positive
# 50079  639979760735662080   neutral
# 50080  640196838260363269   neutral
# 50081  640975710354567168  positive
# 50082  641034340068143104   neutral
#
#                                                                                                                                             Tweet
# 0                     Won the match #getin . Plus\u002c tomorrow is a very busy day\u002c with Awareness Day\u2019s and debates. Gulp. Debates...
# 1                                                                     Some areas of New England could see the first flakes of the season Tuesday.
# 2               @francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.
# 3        #Thailand Washington - US President Barack Obama vowed Wednesday as he visited storm-ravaged New Jersey shore to... http://t.co/Xzl4LFhs
# 4      Did y\u2019all hear what Tony Romo dressed up as for Halloween? A Giants quaterback! Cause that\u2019s all he could throw to sunday night.
# ...                                                                                                                                           ...
# 50078                                              @Racalto_SK ok good to know. Punting at MetLife in December is a task just hope hes up for it.
# 50079                                         everyone who sat around me at metlife was so annoying but i didnt let it ruin such an amazing night
# 50080                                                              what giants or niners fans would wanna go to the sunday night game at Metlife?
# 50081                                                                             Anybody want a ticket for tomorrow Colombia vs Peru at MetLife?
# 50082                                                    Mendez told me he'd drive me to MetLife on Sunday... My reaction: http://t.co/mUa1e0zrdC
#
# [50083 rows x 3 columns]

# %% [markdown]
# #### Tweet Cleanup

# %%
training_data = training_data.drop_duplicates()
training_data
# Out:
#                        ID Sentiment  \
# 0      260097528899452929   neutral
# 1      263791921753882624   neutral
# 2      264194578381410304  negative
# 3      264041328420204544   neutral
# 4      263816256640126976   neutral
# ...                   ...       ...
# 50078  639855845958885376  positive
# 50079  639979760735662080   neutral
# 50080  640196838260363269   neutral
# 50081  640975710354567168  positive
# 50082  641034340068143104   neutral
#
#                                                                                                                                             Tweet
# 0                     Won the match #getin . Plus\u002c tomorrow is a very busy day\u002c with Awareness Day\u2019s and debates. Gulp. Debates...
# 1                                                                     Some areas of New England could see the first flakes of the season Tuesday.
# 2               @francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.
# 3        #Thailand Washington - US President Barack Obama vowed Wednesday as he visited storm-ravaged New Jersey shore to... http://t.co/Xzl4LFhs
# 4      Did y\u2019all hear what Tony Romo dressed up as for Halloween? A Giants quaterback! Cause that\u2019s all he could throw to sunday night.
# ...                                                                                                                                           ...
# 50078                                              @Racalto_SK ok good to know. Punting at MetLife in December is a task just hope hes up for it.
# 50079                                         everyone who sat around me at metlife was so annoying but i didnt let it ruin such an amazing night
# 50080                                                              what giants or niners fans would wanna go to the sunday night game at Metlife?
# 50081                                                                             Anybody want a ticket for tomorrow Colombia vs Peru at MetLife?
# 50082                                                    Mendez told me he'd drive me to MetLife on Sunday... My reaction: http://t.co/mUa1e0zrdC
#
# [49418 rows x 3 columns]

# %%
#remove unicode from the tweets
training_data['Tweet'] = training_data['Tweet'].str.replace('\\\\u002c', ',')
training_data['Tweet'] = training_data['Tweet'].str.replace('\\\\u2019', "'")
training_data['Tweet'] = training_data['Tweet'].str.replace('\\\\""', '')
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
training_data
# Out:
#                        ID Sentiment  \
# 0      260097528899452929   neutral
# 1      263791921753882624   neutral
# 2      264194578381410304  negative
# 3      264041328420204544   neutral
# 4      263816256640126976   neutral
# ...                   ...       ...
# 50078  639855845958885376  positive
# 50079  639979760735662080   neutral
# 50080  640196838260363269   neutral
# 50081  640975710354567168  positive
# 50082  641034340068143104   neutral
#
#                                                                                                                                           Tweet
# 0                                  Won the match #getin . Plus, tomorrow is a very busy day, with Awareness Day's and debates. Gulp. Debates...
# 1                                                                   Some areas of New England could see the first flakes of the season Tuesday.
# 2             @francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.
# 3      #Thailand Washington - US President Barack Obama vowed Wednesday as he visited storm-ravaged New Jersey shore to... http://t.co/Xzl4LFhs
# 4              Did y'all hear what Tony Romo dressed up as for Halloween? A Giants quaterback! Cause that's all he could throw to sunday night.
# ...                                                                                                                                         ...
# 50078                                            @Racalto_SK ok good to know. Punting at MetLife in December is a task just hope hes up for it.
# 50079                                       everyone who sat around me at metlife was so annoying but i didnt let it ruin such an amazing night
# 50080                                                            what giants or niners fans would wanna go to the sunday night game at Metlife?
# 50081                                                                           Anybody want a ticket for tomorrow Colombia vs Peru at MetLife?
# 50082                                                  Mendez told me he'd drive me to MetLife on Sunday... My reaction: http://t.co/mUa1e0zrdC
#
# [49418 rows x 3 columns]

# %%
#replace classes text to numbers
training_data['Sentiment'] = training_data['Sentiment'].replace('negative', 0)
training_data['Sentiment'] = training_data['Sentiment'].replace('neutral', 1)
training_data['Sentiment'] = training_data['Sentiment'].replace('positive', 2)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
training_data['Sentiment'].value_counts()
# Out:
# 1    22175
# 2    19552
# 0     7691
# Name: Sentiment, dtype: int64

# %% [markdown]
# There is a class imbalance from the SemEval Tweets, will add previously labelled negative tweets from another dataset into the training data set.

# %%
col_titles = ['ID', 'Tweet', 'Sentiment']
training_data = training_data.reindex(columns=col_titles)

# %%
training_data
# Out:
#                        ID  \
# 0      260097528899452929
# 1      263791921753882624
# 2      264194578381410304
# 3      264041328420204544
# 4      263816256640126976
# ...                   ...
# 50078  639855845958885376
# 50079  639979760735662080
# 50080  640196838260363269
# 50081  640975710354567168
# 50082  641034340068143104
#
#                                                                                                                                           Tweet  \
# 0                                  Won the match #getin . Plus, tomorrow is a very busy day, with Awareness Day's and debates. Gulp. Debates...
# 1                                                                   Some areas of New England could see the first flakes of the season Tuesday.
# 2             @francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.
# 3      #Thailand Washington - US President Barack Obama vowed Wednesday as he visited storm-ravaged New Jersey shore to... http://t.co/Xzl4LFhs
# 4              Did y'all hear what Tony Romo dressed up as for Halloween? A Giants quaterback! Cause that's all he could throw to sunday night.
# ...                                                                                                                                         ...
# 50078                                            @Racalto_SK ok good to know. Punting at MetLife in December is a task just hope hes up for it.
# 50079                                       everyone who sat around me at metlife was so annoying but i didnt let it ruin such an amazing night
# 50080                                                            what giants or niners fans would wanna go to the sunday night game at Metlife?
# 50081                                                                           Anybody want a ticket for tomorrow Colombia vs Peru at MetLife?
# 50082                                                  Mendez told me he'd drive me to MetLife on Sunday... My reaction: http://t.co/mUa1e0zrdC
#
#        Sentiment
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1
# ...          ...
# 50078          2
# 50079          1
# 50080          1
# 50081          2
# 50082          1
#
# [49418 rows x 3 columns]

# %%
negative_sample = pd.read_csv('data/sentiment140/negative_sample_addin.csv', index_col=0)

# %%
negative_sample
# Out:
#                 ID  \
# 670935  2246713398
# 649589  2237331866
# 2028    1468288564
# 669856  2246385590
# 458897  2072038618
# ...            ...
# 223543  1977229871
# 274262  1990568686
# 101175  1794321826
# 384644  2053449275
# 285779  1993705813
#
#                                                                                                                                             Tweet  \
# 670935                                                                                       @TheRealScarab PA system bugs are a bummer, sorry.
# 649589  oh daaamnnn! the firemen ball's on the 14th and i'll still be in Cannes  So many handsome men united 2gether, and i miss it! *out tonite*
# 2028                                                                                                  I don't want to be cold in April, but I am
# 669856           @JaredOngie haha its too cold down here  bt other than that im quite fine.. jst extremely bored  wht are your plans for the day?
# 458897                                                                                                                Upset I can't find my CHI!
# ...                                                                                                                                           ...
# 223543                                                                              Sounders are down 0-1 against the Columbus crew at the half.
# 274262                                                                           Prayers for the family of the air France plane that is missing.
# 101175                                                                                                                @pianoduet  we miss you too
# 384644                                                                                                           never felt so down in the dumps
# 285779                                                                                                            great weekend but tomorrow bio
#
#         Sentiment
# 670935          0
# 649589          0
# 2028            0
# 669856          0
# 458897          0
# ...           ...
# 223543          0
# 274262          0
# 101175          0
# 384644          0
# 285779          0
#
# [12230 rows x 3 columns]

# %%
training_data = training_data.append(negative_sample)
training_data = training_data.reset_index(drop=True)
training_data
# Out:
#                        ID  \
# 0      260097528899452929
# 1      263791921753882624
# 2      264194578381410304
# 3      264041328420204544
# 4      263816256640126976
# ...                   ...
# 61643          1977229871
# 61644          1990568686
# 61645          1794321826
# 61646          2053449275
# 61647          1993705813
#
#                                                                                                                                           Tweet  \
# 0                                  Won the match #getin . Plus, tomorrow is a very busy day, with Awareness Day's and debates. Gulp. Debates...
# 1                                                                   Some areas of New England could see the first flakes of the season Tuesday.
# 2             @francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.
# 3      #Thailand Washington - US President Barack Obama vowed Wednesday as he visited storm-ravaged New Jersey shore to... http://t.co/Xzl4LFhs
# 4              Did y'all hear what Tony Romo dressed up as for Halloween? A Giants quaterback! Cause that's all he could throw to sunday night.
# ...                                                                                                                                         ...
# 61643                                                                             Sounders are down 0-1 against the Columbus crew at the half.
# 61644                                                                          Prayers for the family of the air France plane that is missing.
# 61645                                                                                                               @pianoduet  we miss you too
# 61646                                                                                                          never felt so down in the dumps
# 61647                                                                                                           great weekend but tomorrow bio
#
#        Sentiment
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1
# ...          ...
# 61643          0
# 61644          0
# 61645          0
# 61646          0
# 61647          0
#
# [61648 rows x 3 columns]

# %%
training_data['Sentiment'].value_counts()
# Out:
# 1    22175
# 0    19921
# 2    19552
# Name: Sentiment, dtype: int64

# %%
#create a copy of dataframe to keep original tweet text
training_data_full_tweets = training_data.copy()

# %%
def remove_stopwords(tweet):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["not", "no"]
    words = tweet.split() 
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1] 
    return " ".join(clean_words)

# %%
def tweet_cleaner(tweet_column):
    #remove links
    tweet_column = tweet_column.str.replace('\w+:\/\/\S+', '', case=False)
    #remove @user
    tweet_column = tweet_column.str.replace('@[A-Za-z0-9_]+', '')
    #remove underscores
    tweet_column = tweet_column.str.replace('_', ' ')
    #remove apostrophes
    tweet_column = tweet_column.str.replace("'", '')
    #remove hashtags
    tweet_column = tweet_column.str.replace('#[A-Za-z0-9]+', '')
    #remove punctuation 
    tweet_column = tweet_column.str.replace("[^\w\d\s#’]", " ")
    #lower case
    tweet_column = tweet_column.str.lower()
    #remove whitespace
    tweet_column = tweet_column.str.replace(r'\s\s+', ' ')
    #remove beginning and end whitespace
    tweet_column = tweet_column.str.lstrip(' ')
    tweet_column = tweet_column.str.rstrip(' ')
    
    return tweet_column

# %%
training_data['Tweet'] = training_data['Tweet'].apply(remove_stopwords)

# %%
training_data['Tweet'] = tweet_cleaner(training_data['Tweet'])

# %%
training_data
# Out:
#                        ID  \
# 0      260097528899452929
# 1      263791921753882624
# 2      264194578381410304
# 3      264041328420204544
# 4      263816256640126976
# ...                   ...
# 61643          1977229871
# 61644          1990568686
# 61645          1794321826
# 61646          2053449275
# 61647          1993705813
#
#                                                                                                   Tweet  \
# 0                                  won match plus tomorrow busy day awareness days debates gulp debates
# 1                                          some areas new england could see first flakes season tuesday
# 2                    2nd worst qb definitely tony romo the man likes share ball everyone including team
# 3        washington us president barack obama vowed wednesday visited storm ravaged new jersey shore to
# 4      did yall hear tony romo dressed halloween giants quaterback cause thats could throw sunday night
# ...                                                                                                 ...
# 61643                                                                   sounders 0 1 columbus crew half
# 61644                                                           prayers family air france plane missing
# 61645                                                                                              miss
# 61646                                                                                  never felt dumps
# 61647                                                                        great weekend tomorrow bio
#
#        Sentiment
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1
# ...          ...
# 61643          0
# 61644          0
# 61645          0
# 61646          0
# 61647          0
#
# [61648 rows x 3 columns]

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61648 entries, 0 to 61647
# Data columns (total 3 columns):
# ID           61648 non-null int64
# Tweet        61648 non-null object
# Sentiment    61648 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.4+ MB

# %%
training_data.to_csv('data/SemEval Tweets/cleaned_training_data.csv')

# %% [markdown]
# #### Tokenizer (Removes stop-words, then lemmatizes tokens)

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
def my_tokenizer(sentence):

    listofwords = sentence.split(' ')
    listofstemmed_words = []
    
    for word in listofwords:
        # Stem words
        lemmatized_word = lemmatizer.lemmatize(word)
        listofstemmed_words.append(lemmatized_word)

    return listofstemmed_words

# %% [markdown]
# Now, I will use both CountVectorizer and TFIDFVectorizer to see which gives the best accuracy.

# %% [markdown]
# #### CountVectorizer

# %%
#THIS CELL TAKES A WHILE TO RUN
X_train, X_test, y_train, y_test = train_test_split(training_data['Tweet'], training_data['Sentiment'], test_size=0.2, random_state=1, stratify=training_data['Sentiment'])

countvec = CountVectorizer(min_df=5, tokenizer = my_tokenizer, ngram_range = (1,3)).fit(X_train)
X_train = countvec.transform(X_train)

scores = cross_val_score(LogisticRegression(), X_train, y_train, cv=5)
print(f"Mean cross-validation accuracy: {np.mean(scores)}")
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Mean cross-validation accuracy: 0.6898696702585931

# %%
X_test = countvec.transform(X_test)
countvec_model = LogisticRegression().fit(X_train, y_train)
countvec_model.score(X_test, y_test)
# Out:
# 0.6966747769667477

# %%
#sklearn classification report
y_pred = countvec_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      3984
#            1       0.63      0.66      0.65      4435
#            2       0.69      0.64      0.67      3911
#
#     accuracy                           0.70     12330
#    macro avg       0.70      0.70      0.70     12330
# weighted avg       0.70      0.70      0.70     12330

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[3154,  599,  231],
#        [ 624, 2926,  885],
#        [ 299, 1102, 2510]], dtype=int64)

# %% [markdown]
# #### TfidfVectorizer

# %%
#THIS CELL TAKES A WHILE TO RUN
X_train, X_test, y_train, y_test = train_test_split(training_data['Tweet'], training_data['Sentiment'], test_size=0.2, random_state=1, stratify=training_data['Sentiment'])

tfidfvec = TfidfVectorizer(min_df=5, tokenizer = my_tokenizer, ngram_range=(1,3)).fit(X_train)
X_train = tfidfvec.transform(X_train)

# %%
scores = cross_val_score(LogisticRegression(), X_train, y_train, cv=5)
print(f"Mean cross-validation accuracy: {np.mean(scores)}")
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Mean cross-validation accuracy: 0.6962972701709236

# %%
X_test = tfidfvec.transform(X_test)
tfidf_model = LogisticRegression().fit(X_train, y_train)
tfidf_model.score(X_test, y_test)
# Out:
# 0.6988645579886456

# %%
#sklearn classification report
y_pred = tfidf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77      3984
#            1       0.63      0.71      0.66      4435
#            2       0.71      0.63      0.67      3911
#
#     accuracy                           0.70     12330
#    macro avg       0.71      0.70      0.70     12330
# weighted avg       0.70      0.70      0.70     12330

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[3025,  700,  259],
#        [ 550, 3131,  754],
#        [ 291, 1159, 2461]], dtype=int64)

# %% [markdown]
# #### Test both vectorizers with assorted classifiers

# %%
logreg = LogisticRegression()
forest = RandomForestClassifier()
xg = XGBClassifier()
svc = LinearSVC()
bayes = MultinomialNB()

# %% [markdown]
# CountVectorizer

# %%
classifiers = [logreg, forest, xg, svc, bayes]
acc_train = []
acc_test = []

# %%
#THIS CELL TAKES A WHILE TO RUN
for i in classifiers:
    X_train, X_test, y_train, y_test = train_test_split(training_data['Tweet'], training_data['Sentiment'], test_size=0.2, random_state=1, stratify=training_data['Sentiment'])

    countvec = CountVectorizer(min_df=5, tokenizer = my_tokenizer, ngram_range = (1,3)).fit(X_train)
    X_train = countvec.transform(X_train)

    scores = cross_val_score(i, X_train, y_train, cv=5)
    acc_train.append(np.mean(scores))
    
    X_test = countvec.transform(X_test)
    model = i.fit(X_train, y_train)
    acc_test.append(model.score(X_test, y_test))
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
summary_countvec = pd.DataFrame({'model': classifiers,
              'Training Accuracy': acc_train,
              'Test Accuracy': acc_test})
summary_countvec
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      model  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,\n                   intercept_scaling=1, l1_ratio=None, max_iter=100,\n                   multi_class='warn', n_jobs=None, penalty='l2',\n                   random_state=None, solver='warn', tol=0.0001, verbose=0,\n                   warm_start=False)
# 1  (DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,\n                       max_features='auto', max_leaf_nodes=None,\n                       min_impurity_decrease=0.0, min_impurity_split=None,\n                       min_samples_leaf=1, min_samples_split=2,\n                       min_weight_fraction_leaf=0.0, presort=False,\n                       random_state=1044220845, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,\n                       max_features='auto', max_leaf_nodes=None,\n                       min_impurity_decrease=0.0, min_impurity_split=None,\n                       min_samples_leaf=1, min_samples_split=2,\n                       min_weight_fraction_leaf=0.0, presort=False,\n                       random_state=452342138, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,\n                       max_features='auto', max_leaf_nodes=None,\n               ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,\n              colsample_bynode=1, colsample_bytree=1, gamma=0,\n              learning_rate=0.1, max_delta_step=0, max_depth=3,\n              min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,\n              nthread=None, objective='multi:softprob', random_state=0,\n              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,\n              silent=None, subsample=1, verbosity=1)
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,\n          intercept_scaling=1, loss='squared_hinge', max_iter=1000,\n          multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,\n          verbose=0)
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
#
#    Training Accuracy  Test Accuracy
# 0           0.689870       0.696675
# 1           0.612352       0.616869
# 2           0.602052       0.601784
# 3           0.648992       0.661557
# 4           0.662070       0.659205

# %% [markdown]
# TfidfVectorizer

# %%
acc_train_tfidf = []
acc_test_tfidf = []

# %%
#THIS CELL TAKES A WHILE TO RUN
for i in classifiers:
    X_train, X_test, y_train, y_test = train_test_split(training_data['Tweet'], training_data['Sentiment'], test_size=0.2, random_state=1, stratify=training_data['Sentiment'])

    tfidfvec = TfidfVectorizer(min_df=5, tokenizer = my_tokenizer, ngram_range = (1,3)).fit(X_train)
    X_train = tfidfvec.transform(X_train)

    scores = cross_val_score(i, X_train, y_train, cv=5)
    acc_train_tfidf.append(np.mean(scores))
    
    X_test = tfidfvec.transform(X_test)
    model = i.fit(X_train, y_train)
    acc_test_tfidf.append(model.score(X_test, y_test))
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
summary_tfidfvec = pd.DataFrame({'model': classifiers,
              'Training Accuracy': acc_train_tfidf,
              'Test Accuracy': acc_test_tfidf})
summary_tfidfvec
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      model  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,\n                   intercept_scaling=1, l1_ratio=None, max_iter=100,\n                   multi_class='warn', n_jobs=None, penalty='l2',\n                   random_state=None, solver='warn', tol=0.0001, verbose=0,\n                   warm_start=False)
# 1  (DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,\n                       max_features='auto', max_leaf_nodes=None,\n                       min_impurity_decrease=0.0, min_impurity_split=None,\n                       min_samples_leaf=1, min_samples_split=2,\n                       min_weight_fraction_leaf=0.0, presort=False,\n                       random_state=1771008734, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,\n                       max_features='auto', max_leaf_nodes=None,\n                       min_impurity_decrease=0.0, min_impurity_split=None,\n                       min_samples_leaf=1, min_samples_split=2,\n                       min_weight_fraction_leaf=0.0, presort=False,\n                       random_state=818047329, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,\n                       max_features='auto', max_leaf_nodes=None,\n               ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,\n              colsample_bynode=1, colsample_bytree=1, gamma=0,\n              learning_rate=0.1, max_delta_step=0, max_depth=3,\n              min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,\n              nthread=None, objective='multi:softprob', random_state=0,\n              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,\n              silent=None, subsample=1, verbosity=1)
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,\n          intercept_scaling=1, loss='squared_hinge', max_iter=1000,\n          multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,\n          verbose=0)
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
#
#    Training Accuracy  Test Accuracy
# 0           0.696297       0.698865
# 1           0.616590       0.624088
# 2           0.603856       0.605109
# 3           0.679914       0.686456
# 4           0.665477       0.663098

# %% [markdown]
# Tfidf Vectorizor with Logisitic Regression has the highest accuracy, therefore we will use this combination for the sentiment analysis model.

# %% [markdown]
# #### Remove tweets from model that model is not confident in classifying (< 40%)

# %% [markdown]
# For tweets that have

# %%
X = training_data['Tweet']
X = tfidfvec.transform(X)
prediction = tfidf_model.predict(X)
predicted_prob = tfidf_model.predict_proba(X)

# %%
training_data['Prediction'] = prediction
training_data_full_tweets['Prediction'] = prediction
predicted_prob_df = pd.DataFrame(predicted_prob, columns=['Neg Prob', 'Neu Prob', 'Pos Prob'])
training_data_full_tweets=pd.concat([training_data_full_tweets, predicted_prob_df], axis=1)
training_data_full_tweets
# Out:
#                        ID  \
# 0      260097528899452929
# 1      263791921753882624
# 2      264194578381410304
# 3      264041328420204544
# 4      263816256640126976
# ...                   ...
# 61643          1977229871
# 61644          1990568686
# 61645          1794321826
# 61646          2053449275
# 61647          1993705813
#
#                                                                                                                                           Tweet  \
# 0                                  Won the match #getin . Plus, tomorrow is a very busy day, with Awareness Day's and debates. Gulp. Debates...
# 1                                                                   Some areas of New England could see the first flakes of the season Tuesday.
# 2             @francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.
# 3      #Thailand Washington - US President Barack Obama vowed Wednesday as he visited storm-ravaged New Jersey shore to... http://t.co/Xzl4LFhs
# 4              Did y'all hear what Tony Romo dressed up as for Halloween? A Giants quaterback! Cause that's all he could throw to sunday night.
# ...                                                                                                                                         ...
# 61643                                                                             Sounders are down 0-1 against the Columbus crew at the half.
# 61644                                                                          Prayers for the family of the air France plane that is missing.
# 61645                                                                                                               @pianoduet  we miss you too
# 61646                                                                                                          never felt so down in the dumps
# 61647                                                                                                           great weekend but tomorrow bio
#
#        Sentiment  Prediction  Neg Prob  Neu Prob  Pos Prob
# 0              1           2  0.163887  0.326970  0.509143
# 1              1           1  0.075077  0.589286  0.335637
# 2              0           0  0.462145  0.256313  0.281542
# 3              1           1  0.106190  0.721355  0.172455
# 4              1           1  0.289144  0.600686  0.110170
# ...          ...         ...       ...       ...       ...
# 61643          0           0  0.521234  0.343331  0.135435
# 61644          0           0  0.783293  0.167084  0.049623
# 61645          0           0  0.943358  0.030950  0.025692
# 61646          0           0  0.656970  0.306617  0.036413
# 61647          0           2  0.189751  0.095410  0.714839
#
# [61648 rows x 7 columns]

# %%
training_data_full_tweets.to_csv('data/SemEval Tweets/complete/training_data_class_probabilities.csv')

# %%
predicted_prob_df
# Out:
#        Neg Prob  Neu Prob  Pos Prob
# 0      0.163887  0.326970  0.509143
# 1      0.075077  0.589286  0.335637
# 2      0.462145  0.256313  0.281542
# 3      0.106190  0.721355  0.172455
# 4      0.289144  0.600686  0.110170
# ...         ...       ...       ...
# 61643  0.521234  0.343331  0.135435
# 61644  0.783293  0.167084  0.049623
# 61645  0.943358  0.030950  0.025692
# 61646  0.656970  0.306617  0.036413
# 61647  0.189751  0.095410  0.714839
#
# [61648 rows x 3 columns]

# %%
bad_class_tweets_list = []
for index, row in predicted_prob_df.iterrows():
    if row['Neg Prob'] < 0.4:
        if row['Neu Prob'] < 0.4:
            if row['Pos Prob'] < 0.4:
                bad_class_tweets_list.append(index)

# %%
print(bad_class_tweets_list)
# Out:
# [23, 34, 44, 83, 88, 95, 112, 115, 184, 202, 204, 245, 256, 278, 319, 343, 365, 378, 402, 431, 441, 462, 473, 485, 488, 489, 530, 531, 567, 587, 621, 633, 676, 737, 743, 749, 761, 770, 785, 794, 807, 870, 950, 968, 982, 992, 1006, 1039, 1051, 1073, 1078, 1163, 1227, 1277, 1284, 1343, 1344, 1346, 1370, 1396, 1415, 1462, 1476, 1492, 1540, 1567, 1571, 1574, 1580, 1583, 1608, 1627, 1633, 1642, 1647, 1650, 1681, 1709, 1761, 1764, 1775, 1791, 1837, 1839, 1913, 1918, 1923, 1930, 1948, 1953, 1954, 1965, 1972, 1981, 2016, 2019, 2040, 2069, 2088, 2108, 2153, 2186, 2196, 2225, 2229, 2248, 2250, 2299, 2318, 2347, 2371, 2379, 2432, 2498, 2506, 2530, 2543, 2564, 2585, 2635, 2656, 2664, 2683, 2717, 2719, 2739, 2750, 2787, 2796, 2816, 2817, 2822, 2859, 2861, 2890, 2919, 2929, 2938, 2949, 2960, 2990, 3025, 3033, 3080, 3089, 3114, 3130, 3140, 3151, 3179, 3203, 3232, 3303, 3364, 3366, 3369, 3370, 3376, 3397, 3471, 3517, 3522, 3544, 3570, 3589, 3597, 3608, 3640, 3648, 3665, 3689, 3736, 3756, 3765, 3774, 3788, 3878, 3959, 3960, 3964, 3965, 3971, 3983, 4011, 4017, 4020, 4105, 4194, 4211, 4293, 4369, 4393, 4408, 4415, 4435, 4457, 4469, 4479, 4498, 4520, 4523, 4532, 4551, 4561, 4669, 4677, 4682, 4709, 4719, 4738, 4746, 4793, 4877, 4895, 4915, 4941, 4945, 4959, 4987, 5007, 5033, 5037, 5081, 5164, 5179, 5230, 5257, 5294, 5315, 5328, 5339, 5346, 5378, 5434, 5445, 5472, 5477, 5484, 5507, 5538, 5562, 5576, 5584, 5591, 5598, 5623, 5635, 5662, 5712, 5727, 5742, 5749, 5770, 5773, 5808, 5812, 5819, 5945, 5946, 5962, 6057, 6084, 6087, 6093, 6135, 6149, 6155, 6169, 6173, 6178, 6259, 6273, 6316, 6319, 6322, 6350, 6362, 6369, 6392, 6410, 6411, 6421, 6440, 6468, 6477, 6489, 6508, 6550, 6562, 6572, 6579, 6651, 6688, 6693, 6696, 6699, 6707, 6743, 6756, 6764, 6845, 6850, 6853, 6901, 6947, 6960, 6980, 6982, 6999, 7007, 7034, 7061, 7185, 7225, 7226, 7238, 7249, 7250, 7254, 7256, 7267, 7295, 7389, 7413, 7418, 7469, 7502, 7509, 7516, 7577, 7611, 7614, 7634, 7635, 7644, 7663, 7664, 7667, 7687, 7699, 7747, 7760, 7763, 7802, 7806, 7930, 7943, 7970, 7996, 8042, 8054, 8067, 8128, 8129, 8133, 8218, 8248, 8299, 8300, 8315, 8318, 8466, 8511, 8521, 8533, 8535, 8618, 8681, 8715, 8732, 8766, 8770, 8786, 8821, 8834, 8883, 8894, 8910, 8931, 9010, 9011, 9017, 9025, 9041, 9056, 9109, 9149, 9181, 9203, 9235, 9298, 9344, 9405, 9456, 9488, 9530, 9586, 9602, 9608, 9611, 9688, 9717, 9750, 9806, 9845, 9866, 9902, 9936, 9953, 9976, 10001, 10008, 10018, 10037, 10056, 10086, 10111, 10115, 10169, 10216, 10220, 10277, 10378, 10453, 10531, 10533, 10597, 10618, 10646, 10668, 10744, 10752, 10781, 10876, 10893, 10940, 10962, 11033, 11086, 11096, 11110, 11123, 11139, 11189, 11227, 11322, 11342, 11344, 11374, 11410, 11424, 11437, 11444, 11448, 11469, 11512, 11558, 11626, 11633, 11638, 11646, 11719, 11728, 11815, 11833, 11875, 11927, 11955, 11968, 11997, 12024, 12096, 12104, 12108, 12111, 12128, 12144, 12151, 12179, 12215, 12245, 12284, 12291, 12335, 12345, 12362, 12391, 12409, 12420, 12426, 12464, 12467, 12473, 12608, 12635, 12646, 12666, 12716, 12757, 12779, 12781, 12785, 12861, 12880, 12885, 13051, 13109, 13127, 13152, 13259, 13264, 13411, 13446, 13467, 13484, 13485, 13561, 13590, 13598, 13605, 13640, 13647, 13715, 13730, 13731, 13777, 13791, 13798, 13807, 13850, 13854, 13884, 13887, 13920, 13931, 13938, 13977, 13986, 14030, 14038, 14081, 14092, 14105, 14157, 14168, 14223, 14227, 14256, 14266, 14292, 14310, 14359, 14379, 14385, 14388, 14391, 14426, 14451, 14505, 14531, 14589, 14647, 14671, 14700, 14717, 14728, 14770, 14780, 14809, 14826, 14855, 14861, 14865, 14866, 14887, 14901, 14942, 14956, 14978, 15023, 15033, 15042, 15044, 15059, 15084, 15156, 15177, 15218, 15291, 15294, 15309, 15399, 15512, 15531, 15545, 15576, 15613, 15661, 15714, 15758, 15828, 15834, 15845, 15853, 15869, 15953, 15959, 16007, 16011, 16029, 16079, 16085, 16096, 16100, 16118, 16125, 16141, 16178, 16188, 16208, 16225, 16273, 16407, 16479, 16507, 16524, 16560, 16561, 16587, 16610, 16611, 16651, 16660, 16672, 16693, 16727, 16731, 16 ...

# %%
training_data
# Out:
#                        ID  \
# 0      260097528899452929
# 1      263791921753882624
# 2      264194578381410304
# 3      264041328420204544
# 4      263816256640126976
# ...                   ...
# 61643          1977229871
# 61644          1990568686
# 61645          1794321826
# 61646          2053449275
# 61647          1993705813
#
#                                                                                                   Tweet  \
# 0                                  won match plus tomorrow busy day awareness days debates gulp debates
# 1                                          some areas new england could see first flakes season tuesday
# 2                    2nd worst qb definitely tony romo the man likes share ball everyone including team
# 3        washington us president barack obama vowed wednesday visited storm ravaged new jersey shore to
# 4      did yall hear tony romo dressed halloween giants quaterback cause thats could throw sunday night
# ...                                                                                                 ...
# 61643                                                                   sounders 0 1 columbus crew half
# 61644                                                           prayers family air france plane missing
# 61645                                                                                              miss
# 61646                                                                                  never felt dumps
# 61647                                                                        great weekend tomorrow bio
#
#        Sentiment  Prediction
# 0              1           2
# 1              1           1
# 2              0           0
# 3              1           1
# 4              1           1
# ...          ...         ...
# 61643          0           0
# 61644          0           0
# 61645          0           0
# 61646          0           0
# 61647          0           2
#
# [61648 rows x 4 columns]

# %%
training_data_full_tweets
# Out:
#                        ID  \
# 0      260097528899452929
# 1      263791921753882624
# 2      264194578381410304
# 3      264041328420204544
# 4      263816256640126976
# ...                   ...
# 61643          1977229871
# 61644          1990568686
# 61645          1794321826
# 61646          2053449275
# 61647          1993705813
#
#                                                                                                                                           Tweet  \
# 0                                  Won the match #getin . Plus, tomorrow is a very busy day, with Awareness Day's and debates. Gulp. Debates...
# 1                                                                   Some areas of New England could see the first flakes of the season Tuesday.
# 2             @francesco_con40 2nd worst QB. DEFINITELY Tony Romo. The man who likes to share the ball with everyone. Including the other team.
# 3      #Thailand Washington - US President Barack Obama vowed Wednesday as he visited storm-ravaged New Jersey shore to... http://t.co/Xzl4LFhs
# 4              Did y'all hear what Tony Romo dressed up as for Halloween? A Giants quaterback! Cause that's all he could throw to sunday night.
# ...                                                                                                                                         ...
# 61643                                                                             Sounders are down 0-1 against the Columbus crew at the half.
# 61644                                                                          Prayers for the family of the air France plane that is missing.
# 61645                                                                                                               @pianoduet  we miss you too
# 61646                                                                                                          never felt so down in the dumps
# 61647                                                                                                           great weekend but tomorrow bio
#
#        Sentiment  Prediction  Neg Prob  Neu Prob  Pos Prob
# 0              1           2  0.163887  0.326970  0.509143
# 1              1           1  0.075077  0.589286  0.335637
# 2              0           0  0.462145  0.256313  0.281542
# 3              1           1  0.106190  0.721355  0.172455
# 4              1           1  0.289144  0.600686  0.110170
# ...          ...         ...       ...       ...       ...
# 61643          0           0  0.521234  0.343331  0.135435
# 61644          0           0  0.783293  0.167084  0.049623
# 61645          0           0  0.943358  0.030950  0.025692
# 61646          0           0  0.656970  0.306617  0.036413
# 61647          0           2  0.189751  0.095410  0.714839
#
# [61648 rows x 7 columns]

# %%
training_data = training_data.drop(bad_class_tweets_list, axis=0)

# %%
training_data
# Out:
#                        ID  \
# 0      260097528899452929
# 1      263791921753882624
# 2      264194578381410304
# 3      264041328420204544
# 4      263816256640126976
# ...                   ...
# 61643          1977229871
# 61644          1990568686
# 61645          1794321826
# 61646          2053449275
# 61647          1993705813
#
#                                                                                                   Tweet  \
# 0                                  won match plus tomorrow busy day awareness days debates gulp debates
# 1                                          some areas new england could see first flakes season tuesday
# 2                    2nd worst qb definitely tony romo the man likes share ball everyone including team
# 3        washington us president barack obama vowed wednesday visited storm ravaged new jersey shore to
# 4      did yall hear tony romo dressed halloween giants quaterback cause thats could throw sunday night
# ...                                                                                                 ...
# 61643                                                                   sounders 0 1 columbus crew half
# 61644                                                           prayers family air france plane missing
# 61645                                                                                              miss
# 61646                                                                                  never felt dumps
# 61647                                                                        great weekend tomorrow bio
#
#        Sentiment  Prediction
# 0              1           2
# 1              1           1
# 2              0           0
# 3              1           1
# 4              1           1
# ...          ...         ...
# 61643          0           0
# 61644          0           0
# 61645          0           0
# 61646          0           0
# 61647          0           2
#
# [60023 rows x 4 columns]

# %%
training_data['Sentiment'].value_counts()
# Out:
# 1    21607
# 0    19467
# 2    18949
# Name: Sentiment, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(training_data['Tweet'], training_data['Sentiment'], test_size=0.2, random_state=1, stratify=training_data['Sentiment'])

tfidfvec_mod = TfidfVectorizer(min_df=5, tokenizer = my_tokenizer, ngram_range=(1,3)).fit(X_train)
X_train = tfidfvec_mod.transform(X_train)

# %%
scores = cross_val_score(LogisticRegression(), X_train, y_train, cv=5)
print(f"Mean cross-validation accuracy: {np.mean(scores)}")
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Mean cross-validation accuracy: 0.7090674006638732

# %%
X_test = tfidfvec_mod.transform(X_test)
tfidf_model_mod = LogisticRegression().fit(X_train, y_train)
tfidf_model_mod.score(X_test, y_test)
# Out:
# 0.7144523115368596

# %% [markdown]
# The accuracy has improved with the low confidence data taken away. Finally, lets optimize the C value.

# %% [markdown]
# #### Hyperparameter Optimization

# %%
#THIS TAKES A LONG TIME TO RUN
X_train, X_test, y_train, y_test = train_test_split(training_data['Tweet'], training_data['Sentiment'], test_size=0.2, random_state=1, stratify=training_data['Sentiment'])
X_train = tfidfvec.transform(X_train)


tuned_parameters = {'C':[.00000001,.0000001,.000001,.00001,.0001,.001,.01, .1,\
                          1,10,100,1000,10000,100000,1000000,10000000,100000000,1000000000],
                     'penalty': ['l1', 'l2']}


clf = RandomizedSearchCV(LogisticRegression(), tuned_parameters, cv = 5)
search = clf.fit(X_train, y_train)
search.best_params_
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# {'penalty': 'l2', 'C': 1}

# %%
scores_tuned = cross_val_score(LogisticRegression(C=1, penalty='l2'), X_train, y_train, cv=5)
print(f"Mean cross-validation accuracy: {np.mean(scores)}")
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Mean cross-validation accuracy: 0.7090674006638732

# %%
X_test = tfidfvec.transform(X_test)
tfidf_model_tuned = LogisticRegression(C=1, penalty='l2').fit(X_train, y_train)
tfidf_model_tuned.score(X_test, y_test)
# Out:
# 0.7128696376509788

# %% [markdown]
# #### Predict NBA Tweets Sentiment

# %% [markdown]
# Raptors

# %%
raptors = pd.read_csv('data/tweets/raptors/raptors_cleaned_tweets.csv', index_col=0)

# %%
raptors
# Out:
#                            Date  Game Location                   ID  \
# 0     2018-10-09 21:53:14+00:00   Philadelphia  1049855345592557569
# 1     2018-10-10 07:48:14+00:00        Toronto  1050005082748702722
# 2     2018-10-10 09:35:30+00:00        Toronto  1050032078052503552
# 3     2018-10-10 09:42:30+00:00        Toronto  1050033837592535040
# 4     2018-10-10 13:25:37+00:00        Toronto  1050089985922220032
# ...                         ...            ...                  ...
# 3575  2019-04-10 17:42:48+00:00        Toronto  1116109300177489922
# 3576  2019-04-10 17:50:33+00:00        Orlando  1116111251887804417
# 3577  2019-04-10 18:07:30+00:00    Los Angeles  1116115516744065024
# 3578  2019-04-10 18:13:49+00:00        Toronto  1116117106439925765
# 3579  2019-04-10 18:52:37+00:00  Oklahoma City  1116126871547207680
#
#                                                                                                                                                                                                                                              Tweet  \
# 0                                                            She like a bear claw/ She Like Kawhi Leonard/ She tryna lock a nigga right down but imma spin her (OFF THE TOP FREESTYLE) #uproarchallenge #YOUMIDASWELL #offthetop #Freestyle #rap…
# 1                                                                                                                                                                   I’m a Kawhi fan! Just like him, when I laugh, I laugh hard! @Toronto, Ontario
# 2                                                                                                                                       Let’s goooo . . #tangerine #scotiabankarena #acc #basketball #raptors #corporate #rally @Scotiabank Arena
# 3                                                                                                    Excited to get onto the court! . . #tangerine #scotiabankarena #acc #raptors #basketball #corproate #rally #goodtimes #nba @Scotiabank Arena
# 4                                                    @fyinktattoos has tatted Drake, Justin Bieber, the Toronto Raptors...and now this knucklehead. #inktober #inktober2018 #tattoo #tattoos #mannyfacestattoo #fyink mannyfacestattoo #basquiat…
# ...                                                                                                                                                                                                                                            ...
# 3575                                                                                                                                                                                                      You Wanna Play The Raptors First Round?
# 3576                                                                                                                                                                            So who do we want to face?!? Bucks, Raptors, or 76ers?! #puremagic
# 3577                                                                                                                                                     Jerry West isn’t coming BACK. TOO Busy building the tracks to KAWHI for the CLIPP JOINT..
# 3578  He coached Kyle, FVV, Siakam (who’s a totally different player), OG, Norm and ibaka (being used properly unlike how Casey used him). Raptors are a totally different squad Plus Casey notoriously got outcoached. I can’t wait to sweep them
# 3579                                                                                                                                                                                           The Raptors would be a pretty nice fit for him....
#
#                  User
# 0        Youmidaswell
# 1            sivedahk
# 2           AlexHPLai
# 3           AlexHPLai
# 4        Dannysmithxx
# ...               ...
# 3575  Miss_Angel_Baby
# 3576        Gosurf911
# 3577        spurharry
# 3578           Arysaf
# 3579       _Poochie66
#
# [3580 rows x 5 columns]

# %%
raptors_full_tweets = raptors.copy()

# %%
raptors['Tweet'] = tweet_cleaner(raptors['Tweet'])

# %%
raptors_tweets = tfidfvec_mod.transform(raptors['Tweet'])
raptors_pred = tfidf_model_mod.predict(raptors_tweets)

# %%
raptors['Sentiment'] = raptors_pred
raptors_full_tweets['Sentiment'] = raptors_pred

# %%
raptors_full_tweets
# Out:
#                            Date  Game Location                   ID  \
# 0     2018-10-09 21:53:14+00:00   Philadelphia  1049855345592557569
# 1     2018-10-10 07:48:14+00:00        Toronto  1050005082748702722
# 2     2018-10-10 09:35:30+00:00        Toronto  1050032078052503552
# 3     2018-10-10 09:42:30+00:00        Toronto  1050033837592535040
# 4     2018-10-10 13:25:37+00:00        Toronto  1050089985922220032
# ...                         ...            ...                  ...
# 3575  2019-04-10 17:42:48+00:00        Toronto  1116109300177489922
# 3576  2019-04-10 17:50:33+00:00        Orlando  1116111251887804417
# 3577  2019-04-10 18:07:30+00:00    Los Angeles  1116115516744065024
# 3578  2019-04-10 18:13:49+00:00        Toronto  1116117106439925765
# 3579  2019-04-10 18:52:37+00:00  Oklahoma City  1116126871547207680
#
#                                                                                                                                                                                                                                              Tweet  \
# 0                                                            She like a bear claw/ She Like Kawhi Leonard/ She tryna lock a nigga right down but imma spin her (OFF THE TOP FREESTYLE) #uproarchallenge #YOUMIDASWELL #offthetop #Freestyle #rap…
# 1                                                                                                                                                                   I’m a Kawhi fan! Just like him, when I laugh, I laugh hard! @Toronto, Ontario
# 2                                                                                                                                       Let’s goooo . . #tangerine #scotiabankarena #acc #basketball #raptors #corporate #rally @Scotiabank Arena
# 3                                                                                                    Excited to get onto the court! . . #tangerine #scotiabankarena #acc #raptors #basketball #corproate #rally #goodtimes #nba @Scotiabank Arena
# 4                                                    @fyinktattoos has tatted Drake, Justin Bieber, the Toronto Raptors...and now this knucklehead. #inktober #inktober2018 #tattoo #tattoos #mannyfacestattoo #fyink mannyfacestattoo #basquiat…
# ...                                                                                                                                                                                                                                            ...
# 3575                                                                                                                                                                                                      You Wanna Play The Raptors First Round?
# 3576                                                                                                                                                                            So who do we want to face?!? Bucks, Raptors, or 76ers?! #puremagic
# 3577                                                                                                                                                     Jerry West isn’t coming BACK. TOO Busy building the tracks to KAWHI for the CLIPP JOINT..
# 3578  He coached Kyle, FVV, Siakam (who’s a totally different player), OG, Norm and ibaka (being used properly unlike how Casey used him). Raptors are a totally different squad Plus Casey notoriously got outcoached. I can’t wait to sweep them
# 3579                                                                                                                                                                                           The Raptors would be a pretty nice fit for him....
#
#                  User  Sentiment
# 0        Youmidaswell          0
# 1            sivedahk          0
# 2           AlexHPLai          1
# 3           AlexHPLai          2
# 4        Dannysmithxx          2
# ...               ...        ...
# 3575  Miss_Angel_Baby          1
# 3576        Gosurf911          0
# 3577        spurharry          1
# 3578           Arysaf          0
# 3579       _Poochie66          2
#
# [3580 rows x 6 columns]

# %%
raptors['Sentiment'].value_counts()
# Out:
# 0    1440
# 1    1292
# 2     848
# Name: Sentiment, dtype: int64

# %%
raptors_full_tweets.to_csv('data/tweets/raptors/raptors_sentiment_predictions.csv')

# %% [markdown]
# Lakers

# %%
lakers = pd.read_csv('data/tweets/lakers/lakers_cleaned_tweets.csv', index_col=0)

# %%
lakers
# Out:
#                             Date   Game Location                   ID  \
# 0      2018-10-08 17:39:40+00:00       Milwaukee  1049474442789904384
# 1      2018-10-09 10:38:28+00:00         Atlanta  1049730833681125376
# 2      2018-10-09 13:54:20+00:00     Los Angeles  1049780125418606605
# 3      2018-10-09 16:07:20+00:00     Los Angeles  1049813596878921728
# 4      2018-10-09 16:49:13+00:00       Milwaukee  1049824137630367745
# ...                          ...             ...                  ...
# 15421  2019-04-10 15:45:53+00:00     San Antonio  1116125179011268608
# 15422  2019-04-10 15:47:05+00:00     New Orleans  1116125477746413568
# 15423  2019-04-10 15:49:54+00:00     San Antonio  1116126186067906562
# 15424  2019-04-10 15:53:11+00:00     New Orleans  1116127015365697537
# 15425  2019-04-10 15:53:13+00:00  Salt Lake City  1116127023762563074
#
#                                                                                                                                                                                                                                                                                        Tweet  \
# 0                                                                                                                                                                                                                                       Dawwwg . He killed Lebron fam @Milwaukee, Wisconsin
# 1                                                                                                                                                            2016 Game 7 Kyrie &amp; Lebron!! Ima Trust w/ The Last Shot Fasho #NEA #NeverEatAlone #HavinSum2Do #ang ros @Lithonia, Georgia
# 2                                                                                              The Forum opened it’s doors on December 30, 1967 with a seating capacity of 17,500 and this historic venue was home to the NBA’s Los Angeles Lakers and LA Kings from 1967 to 1999. Between…
# 3                                                                                                 @ZO2_ and @kingjames on Lonzo return from injury “No nerves just happy to be back” - @ZO2_ , “It doesn’t seem like he’s had anything done on his knee” - @kingjames @lakers vs @warriors…
# 4                                                                                                How often do we encourage kids to do what they love? We don’t tell them be the next Lebron, or the next Michael Jackson. We say Utilize Time, and just be YOU! (1/2) @Milwaukee, Wisconsin
# ...                                                                                                                                                                                                                                                                                      ...
# 15421                                                                                                                  Alex has worked hard the past 2 years and showed improvement. He plays hard and I appreciate that. Good floor vision and playmaking but will that be enough? #Lakers
# 15422                                                                                                                              Yeah the game after the all star break when we started to say fuck ad and start tanking but they beat the shit ot the Lakers to show them they ain't shit
# 15423  I think Luke did a good job this year for what he was given. Theres not another coach I think could have done better. But he's still a young coach and learning. He doesn't know everything but I like his overall demeanor/style. Would only replace with a top notch coach #Lakers
# 15424   Dude wtf you are lost as shit. like trying to argue with a 4 yr old. I said and showed proof that the pels young core was better then the Lakers team as a whole in feburary after the trade demand when we beat their ass. That was before we started tanking. You are lost as fuck
# 15425                                                                                                                                       Everywhere LeBron goes, great people around him leave. No different in Los Angeles. Terrible leader. Terrible teammate. I’d trade him tomorrow.
#
#                   User
# 0            DJKAOS414
# 1             Mare_nea
# 2             LABlue43
# 3      MikeandDrewShow
# 4             tapdnmag
# ...                ...
# 15421          Cap_180
# 15422     KennethHouck
# 15423          Cap_180
# 15424     KennethHouck
# 15425        Yo_Geertz
#
# [15426 rows x 5 columns]

# %%
lakers_full_tweets = lakers.copy()

# %%
lakers['Tweet'] = tweet_cleaner(lakers['Tweet'])

# %%
lakers_tweets = tfidfvec_mod.transform(lakers['Tweet'])
lakers_pred = tfidf_model_mod.predict(lakers_tweets)

# %%
lakers['Sentiment'] = lakers_pred
lakers_full_tweets['Sentiment'] = lakers_pred

# %%
lakers_full_tweets
# Out:
#                             Date   Game Location                   ID  \
# 0      2018-10-08 17:39:40+00:00       Milwaukee  1049474442789904384
# 1      2018-10-09 10:38:28+00:00         Atlanta  1049730833681125376
# 2      2018-10-09 13:54:20+00:00     Los Angeles  1049780125418606605
# 3      2018-10-09 16:07:20+00:00     Los Angeles  1049813596878921728
# 4      2018-10-09 16:49:13+00:00       Milwaukee  1049824137630367745
# ...                          ...             ...                  ...
# 15421  2019-04-10 15:45:53+00:00     San Antonio  1116125179011268608
# 15422  2019-04-10 15:47:05+00:00     New Orleans  1116125477746413568
# 15423  2019-04-10 15:49:54+00:00     San Antonio  1116126186067906562
# 15424  2019-04-10 15:53:11+00:00     New Orleans  1116127015365697537
# 15425  2019-04-10 15:53:13+00:00  Salt Lake City  1116127023762563074
#
#                                                                                                                                                                                                                                                                                        Tweet  \
# 0                                                                                                                                                                                                                                       Dawwwg . He killed Lebron fam @Milwaukee, Wisconsin
# 1                                                                                                                                                            2016 Game 7 Kyrie &amp; Lebron!! Ima Trust w/ The Last Shot Fasho #NEA #NeverEatAlone #HavinSum2Do #ang ros @Lithonia, Georgia
# 2                                                                                              The Forum opened it’s doors on December 30, 1967 with a seating capacity of 17,500 and this historic venue was home to the NBA’s Los Angeles Lakers and LA Kings from 1967 to 1999. Between…
# 3                                                                                                 @ZO2_ and @kingjames on Lonzo return from injury “No nerves just happy to be back” - @ZO2_ , “It doesn’t seem like he’s had anything done on his knee” - @kingjames @lakers vs @warriors…
# 4                                                                                                How often do we encourage kids to do what they love? We don’t tell them be the next Lebron, or the next Michael Jackson. We say Utilize Time, and just be YOU! (1/2) @Milwaukee, Wisconsin
# ...                                                                                                                                                                                                                                                                                      ...
# 15421                                                                                                                  Alex has worked hard the past 2 years and showed improvement. He plays hard and I appreciate that. Good floor vision and playmaking but will that be enough? #Lakers
# 15422                                                                                                                              Yeah the game after the all star break when we started to say fuck ad and start tanking but they beat the shit ot the Lakers to show them they ain't shit
# 15423  I think Luke did a good job this year for what he was given. Theres not another coach I think could have done better. But he's still a young coach and learning. He doesn't know everything but I like his overall demeanor/style. Would only replace with a top notch coach #Lakers
# 15424   Dude wtf you are lost as shit. like trying to argue with a 4 yr old. I said and showed proof that the pels young core was better then the Lakers team as a whole in feburary after the trade demand when we beat their ass. That was before we started tanking. You are lost as fuck
# 15425                                                                                                                                       Everywhere LeBron goes, great people around him leave. No different in Los Angeles. Terrible leader. Terrible teammate. I’d trade him tomorrow.
#
#                   User  Sentiment
# 0            DJKAOS414          0
# 1             Mare_nea          1
# 2             LABlue43          1
# 3      MikeandDrewShow          0
# 4             tapdnmag          2
# ...                ...        ...
# 15421          Cap_180          0
# 15422     KennethHouck          0
# 15423          Cap_180          0
# 15424     KennethHouck          0
# 15425        Yo_Geertz          0
#
# [15426 rows x 6 columns]

# %%
lakers['Sentiment'].value_counts()
# Out:
# 0    8276
# 1    4559
# 2    2591
# Name: Sentiment, dtype: int64

# %%
lakers_full_tweets.to_csv('data/tweets/lakers/lakers_sentiment_predictions.csv')

# %% [markdown]
# Rockets

# %%
rockets = pd.read_csv('data/tweets/rockets/rockets_cleaned_tweets.csv', index_col=0)

# %%
rockets
# Out:
#                            Date  Game Location                   ID  \
# 0     2018-10-08 21:34:05+00:00  San Francisco  1049503239538954240
# 1     2018-10-09 18:28:40+00:00        Houston  1049818966410059776
# 2     2018-10-09 18:34:31+00:00        Houston  1049820436526223361
# 3     2018-10-09 19:03:50+00:00        Houston  1049827813497421830
# 4     2018-10-09 20:01:18+00:00        Houston  1049842276158070784
# ...                         ...            ...                  ...
# 6179  2019-04-10 17:24:28+00:00    Los Angeles  1116119789468958721
# 6180  2019-04-10 17:29:04+00:00        Toronto  1116120945347817472
# 6181  2019-04-10 17:30:33+00:00        Houston  1116121317424676864
# 6182  2019-04-10 17:52:31+00:00         Boston  1116126844607238144
# 6183  2019-04-10 17:55:22+00:00        Houston  1116127562697195522
#
#                                                                                                                                                                                               Tweet  \
# 0                                        “We are search lights, we can see in the dark, We are rockets, pointing up at the stars, We are billions of beautiful hearts” @San Francisco-Oakland Bay…
# 1                   Are you Melo or Harden pregame? @houstonrockets . . . . #stayme7o #carmeloanthony #Rockets #houstonrockets #shanghai #jamesharden #houston #thisiswhyweplay #carmelo #yaoming…
# 2                                                                                                                                 Supporting the @houstonrockets #runitback @Houston Toyota Center
# 3                                                                                                       Let’s go Rockets! (at @ToyotaCenter for Shanghai Sharks vs Houston Rockets in Houston, TX)
# 4     Yes it’s that time where all my social media will be flooded with everything #HoustonRockets #rocketsfan4life #RunItBack #RunAsOne @houstonrockets #DieHard @jharden13 @cp3 @carmeloanthony…
# ...                                                                                                                                                                                             ...
# 6179                                                                                                                was last night/this morning’s discussion about my lust for rocket a fever dream
# 6180                                                                                When you know Jim Harden is there.... because James Harden goes on vacation every time the regular season ends
# 6181                                                 @Esther188rod YOU HAVE IT RIGHT JAMES HARDEN AND ALL OUR ROCKETS RUN AS ONE GOOD LUCK ON WHO EVER YOU'LL HAVE TO PLAY LOVE ALL OF YOU ROCKETS
# 6182                                                                                                                   James harden wouldn’t be shit without the refs, tell me I’m wrong I got time
# 6183                                                                                                                                                                                   Choke time ?
#
#                  User
# 0            LiFreyre
# 1     MikeandDrewShow
# 2             vet5640
# 3          britneyIRL
# 4       noreenroxanna
# ...               ...
# 6179    rocketlovebot
# 6180        TheHusayn
# 6181     Esther188rod
# 6182        easy_ed25
# 6183          ybg_von
#
# [6184 rows x 5 columns]

# %%
rockets_full_tweets = rockets.copy()

# %%
rockets['Tweet'] = tweet_cleaner(rockets['Tweet'])

# %%
rockets_tweets = tfidfvec_mod.transform(rockets['Tweet'])
rockets_pred = tfidf_model_mod.predict(rockets_tweets)

# %%
rockets['Sentiment'] = rockets_pred
rockets_full_tweets['Sentiment'] = rockets_pred

# %%
rockets_full_tweets
# Out:
#                            Date  Game Location                   ID  \
# 0     2018-10-08 21:34:05+00:00  San Francisco  1049503239538954240
# 1     2018-10-09 18:28:40+00:00        Houston  1049818966410059776
# 2     2018-10-09 18:34:31+00:00        Houston  1049820436526223361
# 3     2018-10-09 19:03:50+00:00        Houston  1049827813497421830
# 4     2018-10-09 20:01:18+00:00        Houston  1049842276158070784
# ...                         ...            ...                  ...
# 6179  2019-04-10 17:24:28+00:00    Los Angeles  1116119789468958721
# 6180  2019-04-10 17:29:04+00:00        Toronto  1116120945347817472
# 6181  2019-04-10 17:30:33+00:00        Houston  1116121317424676864
# 6182  2019-04-10 17:52:31+00:00         Boston  1116126844607238144
# 6183  2019-04-10 17:55:22+00:00        Houston  1116127562697195522
#
#                                                                                                                                                                                               Tweet  \
# 0                                        “We are search lights, we can see in the dark, We are rockets, pointing up at the stars, We are billions of beautiful hearts” @San Francisco-Oakland Bay…
# 1                   Are you Melo or Harden pregame? @houstonrockets . . . . #stayme7o #carmeloanthony #Rockets #houstonrockets #shanghai #jamesharden #houston #thisiswhyweplay #carmelo #yaoming…
# 2                                                                                                                                 Supporting the @houstonrockets #runitback @Houston Toyota Center
# 3                                                                                                       Let’s go Rockets! (at @ToyotaCenter for Shanghai Sharks vs Houston Rockets in Houston, TX)
# 4     Yes it’s that time where all my social media will be flooded with everything #HoustonRockets #rocketsfan4life #RunItBack #RunAsOne @houstonrockets #DieHard @jharden13 @cp3 @carmeloanthony…
# ...                                                                                                                                                                                             ...
# 6179                                                                                                                was last night/this morning’s discussion about my lust for rocket a fever dream
# 6180                                                                                When you know Jim Harden is there.... because James Harden goes on vacation every time the regular season ends
# 6181                                                 @Esther188rod YOU HAVE IT RIGHT JAMES HARDEN AND ALL OUR ROCKETS RUN AS ONE GOOD LUCK ON WHO EVER YOU'LL HAVE TO PLAY LOVE ALL OF YOU ROCKETS
# 6182                                                                                                                   James harden wouldn’t be shit without the refs, tell me I’m wrong I got time
# 6183                                                                                                                                                                                   Choke time ?
#
#                  User  Sentiment
# 0            LiFreyre          2
# 1     MikeandDrewShow          1
# 2             vet5640          1
# 3          britneyIRL          1
# 4       noreenroxanna          0
# ...               ...        ...
# 6179    rocketlovebot          0
# 6180        TheHusayn          1
# 6181     Esther188rod          2
# 6182        easy_ed25          0
# 6183          ybg_von          0
#
# [6184 rows x 6 columns]

# %%
rockets['Sentiment'].value_counts()
# Out:
# 1    2584
# 0    2531
# 2    1069
# Name: Sentiment, dtype: int64

# %%
rockets_full_tweets.to_csv('data/tweets/rockets/rockets_sentiment_predictions.csv')

# %% [markdown]
# Knicks

# %%
knicks = pd.read_csv('data/tweets/knicks/knicks_cleaned_tweets.csv', index_col=0)

# %%
knicks
# Out:
#                            Date Game Location            ID  \
# 0     2018-10-08 20:07:45+00:00      Brooklyn  1.049466e+18
# 1     2018-10-08 20:13:07+00:00      Brooklyn  1.049468e+18
# 2     2018-10-08 21:14:43+00:00      New York  1.049483e+18
# 3     2018-10-08 22:15:42+00:00      Brooklyn  1.049499e+18
# 4     2018-10-09 05:05:06+00:00      Brooklyn  1.049602e+18
# ...                         ...           ...           ...
# 3694  2019-04-10 18:40:32+00:00       Atlanta  1.116124e+18
# 3695  2019-04-10 18:42:46+00:00      Brooklyn  1.116124e+18
# 3696  2019-04-10 18:51:37+00:00      New York  1.116127e+18
# 3697  2019-04-10 18:52:20+00:00      New York  1.116127e+18
# 3698  2019-04-10 18:57:39+00:00      New York  1.116128e+18
#
#                                                                                                                                                                                                                                                                      Tweet  \
# 0                                                                                                                                                                                                            The Knicks still suck #gobulls @Madison Square Garden (1890)
# 1                                                                                                                                                                                                                                           Knicks tip-off!!! @The Garden
# 2                                                                                                                                                                                               I’m bad luck for the Knicks. Thanks @tchristopoul! @Madison Square Garden
# 3                                                                           NY KNICKS vs WASHINGTON WIZARDS #evaedavide #instamoment #picoftheday #evaedavideweddingedition #noi #love #honeymoon #viaggiodinozze #travel #ny #usa #preseason #nba @Madison Square Garden
# 4                                                                                                                                                                                                          Chris Bosh: Fizdale will land Knicks free-agent star they need
# ...                                                                                                                                                                                                                                                                    ...
# 3694                                                                                                             Really hoping the Knicks lose to the Pistons just so I can watch Blake Griffin and Drummond in the Playoffs. Still #NewYorkForever tho! #NBA #NBAPlayoffs
# 3695                                                                                                                                            I can get used to this! #knicks #newyorkknicks #bucketlist #onceaknickalwaysaknick #flyingvsny2019 @Madison Square Garden
# 3696                                                                                                                                                                                                                       It won’t help. Knicks will lose by 20+ tonight
# 3697                                                                                                                                                         So the #Knicks can decide who the 8th seed is... join us afterwards. Who you want in... #Pistons or #Hornets?
# 3698  Covering the last #Knicks game of the season for @wfuvsports. #Pistons need a win to clinch playoffs. #NYK have already clinched NBA’s worst record w/ 17 wins. Team should look very different next time they play here… #NewYorkForever – at Madison Square Garden
#
#                  User
# 0     itsthatmanhowie
# 1     petercbernstein
# 2          APTheAngel
# 3          EvaCoppola
# 4         Sigmaairnyc
# ...               ...
# 3694         SamLimGA
# 3695    daddydribbles
# 3696       cWhitey_NY
# 3697  KnickerbckerAve
# 3698  Jack_Caldwell13
#
# [3699 rows x 5 columns]

# %%
knicks_full_tweets = knicks.copy()

# %%
knicks['Tweet'] = tweet_cleaner(knicks['Tweet'])

# %%
knicks_tweets = tfidfvec_mod.transform(knicks['Tweet'])
knicks_pred = tfidf_model_mod.predict(knicks_tweets)

# %%
knicks['Sentiment'] = knicks_pred
knicks_full_tweets['Sentiment'] = knicks_pred

# %%
knicks_full_tweets
# Out:
#                            Date Game Location            ID  \
# 0     2018-10-08 20:07:45+00:00      Brooklyn  1.049466e+18
# 1     2018-10-08 20:13:07+00:00      Brooklyn  1.049468e+18
# 2     2018-10-08 21:14:43+00:00      New York  1.049483e+18
# 3     2018-10-08 22:15:42+00:00      Brooklyn  1.049499e+18
# 4     2018-10-09 05:05:06+00:00      Brooklyn  1.049602e+18
# ...                         ...           ...           ...
# 3694  2019-04-10 18:40:32+00:00       Atlanta  1.116124e+18
# 3695  2019-04-10 18:42:46+00:00      Brooklyn  1.116124e+18
# 3696  2019-04-10 18:51:37+00:00      New York  1.116127e+18
# 3697  2019-04-10 18:52:20+00:00      New York  1.116127e+18
# 3698  2019-04-10 18:57:39+00:00      New York  1.116128e+18
#
#                                                                                                                                                                                                                                                                      Tweet  \
# 0                                                                                                                                                                                                            The Knicks still suck #gobulls @Madison Square Garden (1890)
# 1                                                                                                                                                                                                                                           Knicks tip-off!!! @The Garden
# 2                                                                                                                                                                                               I’m bad luck for the Knicks. Thanks @tchristopoul! @Madison Square Garden
# 3                                                                           NY KNICKS vs WASHINGTON WIZARDS #evaedavide #instamoment #picoftheday #evaedavideweddingedition #noi #love #honeymoon #viaggiodinozze #travel #ny #usa #preseason #nba @Madison Square Garden
# 4                                                                                                                                                                                                          Chris Bosh: Fizdale will land Knicks free-agent star they need
# ...                                                                                                                                                                                                                                                                    ...
# 3694                                                                                                             Really hoping the Knicks lose to the Pistons just so I can watch Blake Griffin and Drummond in the Playoffs. Still #NewYorkForever tho! #NBA #NBAPlayoffs
# 3695                                                                                                                                            I can get used to this! #knicks #newyorkknicks #bucketlist #onceaknickalwaysaknick #flyingvsny2019 @Madison Square Garden
# 3696                                                                                                                                                                                                                       It won’t help. Knicks will lose by 20+ tonight
# 3697                                                                                                                                                         So the #Knicks can decide who the 8th seed is... join us afterwards. Who you want in... #Pistons or #Hornets?
# 3698  Covering the last #Knicks game of the season for @wfuvsports. #Pistons need a win to clinch playoffs. #NYK have already clinched NBA’s worst record w/ 17 wins. Team should look very different next time they play here… #NewYorkForever – at Madison Square Garden
#
#                  User  Sentiment
# 0     itsthatmanhowie          0
# 1     petercbernstein          1
# 2          APTheAngel          0
# 3          EvaCoppola          1
# 4         Sigmaairnyc          0
# ...               ...        ...
# 3694         SamLimGA          0
# 3695    daddydribbles          0
# 3696       cWhitey_NY          0
# 3697  KnickerbckerAve          1
# 3698  Jack_Caldwell13          2
#
# [3699 rows x 6 columns]

# %%
knicks['Sentiment'].value_counts()
# Out:
# 0    1749
# 1    1461
# 2     489
# Name: Sentiment, dtype: int64

# %%
knicks_full_tweets.to_csv('data/tweets/knicks/knicks_sentiment_predictions.csv')

# %% [markdown]
# Warriors

# %%
warriors = pd.read_csv('data/tweets/warriors/warriors_cleaned_tweets.csv', index_col=0)

# %%
warriors
# Out:
#                            Date  Game Location                   ID  \
# 0     2018-10-08 17:19:14+00:00  San Francisco  1049469303022485504
# 1     2018-10-08 17:29:13+00:00  San Francisco  1049471816014733313
# 2     2018-10-08 18:00:58+00:00  San Francisco  1049479805937340416
# 3     2018-10-08 18:41:23+00:00  San Francisco  1049489975668957184
# 4     2018-10-08 19:40:57+00:00        Memphis  1049504966484905985
# ...                         ...            ...                  ...
# 8687  2019-04-10 15:15:16+00:00        Houston  1116117470723682304
# 8688  2019-04-10 15:15:44+00:00        Chicago  1116117588688474114
# 8689  2019-04-10 15:20:28+00:00        Chicago  1116118779199725569
# 8690  2019-04-10 15:30:05+00:00    Los Angeles  1116121201716318208
# 8691  2019-04-10 15:45:57+00:00  San Francisco  1116125192021893120
#
#                                                                                                                                                                                                 Tweet  \
# 0                                                                          I don't care that it's only preseason @warriors we were here 5hrs early @Oracle Arena and Oakland Alameda County Coliseum
# 1                                                                                                                 Warriors game with my cute date! @Oracle Arena and Oakland Alameda County Coliseum
# 2                                                             GSW vs PHX Preseason Game with the newlyweds @djryano m4uishells #warriors #dubnation #warriorsground @Golden State Warriors Home Game
# 3                                                                         At the warriors game but it's always BULLS all day. #redandblack #seered @Oracle Arena and Oakland Alameda County Coliseum
# 4                                                                                                Teams I (Currently) hate : @AlabamaFTBL New Orleans @Saints Golden State @Warriors New York @Yankees
# ...                                                                                                                                                                                               ...
# 8687                                                                                 Ditto!! How can we help?? You got a global group of warriors who all love you. #callus #textus #smokesignalswork
# 8688                                                                             As NBA fans we were supposed to see CP3, D. Wade, Bron, Melo, and Bosh on one team. Instead we got this Warriors bs.
# 8689                                                                                                                                                                     Tough guy! Keyboard warrior.
# 8690                                                                                                                                                                       I do love my Bomb Warrior!
# 8691  Great list. Agreed @andre should have won a 6th man award for his time with the @warriors but a #nbafinals mvp is a nice consolation prize! We all know his value and I think he knows we know.
#
#                User
# 0     xSunpuddle88x
# 1           timdoll
# 2          itselvis
# 3      TSPENTWENTY3
# 4            JWooTV
# ...             ...
# 8687     28DaysMore
# 8688   MikeJuicedUp
# 8689        dwass34
# 8690       EWOKinLA
# 8691     marcsteiny
#
# [8692 rows x 5 columns]

# %%
warriors_full_tweets = warriors.copy()

# %%
warriors['Tweet'] = tweet_cleaner(warriors['Tweet'])

# %%
warriors_tweets = tfidfvec_mod.transform(warriors['Tweet'])
warriors_pred = tfidf_model_mod.predict(warriors_tweets)

# %%
warriors['Sentiment'] = warriors_pred
warriors_full_tweets['Sentiment'] = warriors_pred

# %%
warriors_full_tweets
# Out:
#                            Date  Game Location                   ID  \
# 0     2018-10-08 17:19:14+00:00  San Francisco  1049469303022485504
# 1     2018-10-08 17:29:13+00:00  San Francisco  1049471816014733313
# 2     2018-10-08 18:00:58+00:00  San Francisco  1049479805937340416
# 3     2018-10-08 18:41:23+00:00  San Francisco  1049489975668957184
# 4     2018-10-08 19:40:57+00:00        Memphis  1049504966484905985
# ...                         ...            ...                  ...
# 8687  2019-04-10 15:15:16+00:00        Houston  1116117470723682304
# 8688  2019-04-10 15:15:44+00:00        Chicago  1116117588688474114
# 8689  2019-04-10 15:20:28+00:00        Chicago  1116118779199725569
# 8690  2019-04-10 15:30:05+00:00    Los Angeles  1116121201716318208
# 8691  2019-04-10 15:45:57+00:00  San Francisco  1116125192021893120
#
#                                                                                                                                                                                                 Tweet  \
# 0                                                                          I don't care that it's only preseason @warriors we were here 5hrs early @Oracle Arena and Oakland Alameda County Coliseum
# 1                                                                                                                 Warriors game with my cute date! @Oracle Arena and Oakland Alameda County Coliseum
# 2                                                             GSW vs PHX Preseason Game with the newlyweds @djryano m4uishells #warriors #dubnation #warriorsground @Golden State Warriors Home Game
# 3                                                                         At the warriors game but it's always BULLS all day. #redandblack #seered @Oracle Arena and Oakland Alameda County Coliseum
# 4                                                                                                Teams I (Currently) hate : @AlabamaFTBL New Orleans @Saints Golden State @Warriors New York @Yankees
# ...                                                                                                                                                                                               ...
# 8687                                                                                 Ditto!! How can we help?? You got a global group of warriors who all love you. #callus #textus #smokesignalswork
# 8688                                                                             As NBA fans we were supposed to see CP3, D. Wade, Bron, Melo, and Bosh on one team. Instead we got this Warriors bs.
# 8689                                                                                                                                                                     Tough guy! Keyboard warrior.
# 8690                                                                                                                                                                       I do love my Bomb Warrior!
# 8691  Great list. Agreed @andre should have won a 6th man award for his time with the @warriors but a #nbafinals mvp is a nice consolation prize! We all know his value and I think he knows we know.
#
#                User  Sentiment
# 0     xSunpuddle88x          0
# 1           timdoll          1
# 2          itselvis          1
# 3      TSPENTWENTY3          2
# 4            JWooTV          0
# ...             ...        ...
# 8687     28DaysMore          2
# 8688   MikeJuicedUp          2
# 8689        dwass34          0
# 8690       EWOKinLA          0
# 8691     marcsteiny          2
#
# [8692 rows x 6 columns]

# %%
warriors['Sentiment'].value_counts()
# Out:
# 0    3624
# 1    3105
# 2    1963
# Name: Sentiment, dtype: int64

# %%
warriors_full_tweets.to_csv('data/tweets/warriors/warriors_sentiment_predictions.csv')

# %% [markdown]
# # Sentiment Effect on Attendance (Linear Regression Models)

# %% [markdown]
# ## Polarized Sentiment Effect (Negative and Positive)

# %%
#function to calculate polarized sentiment (positive+negative/total tweets) prior to games
def polar_sentiment_ratio_calc(attendance_df, team_df):
    attendance_df['Date'] = attendance_df['Date'] + ' ' + attendance_df['Start (ET)']
    team_df['Date'] = pd.to_datetime(team_df['Date'])
    attendance_df['Date'] = pd.DatetimeIndex(pd.to_datetime(attendance_df['Date'])).tz_localize('UTC')
    attendance_df['Polarized Sentiment Ratio'] = np.nan
    for index, row in attendance_df.iterrows():
        if index == 0:
            before_game = team_df[team_df['Date'] < attendance_df['Date'][index]]
            attendance_df['Polarized Sentiment Ratio'][index] = ((before_game['Sentiment'] == 2).sum() + (before_game['Sentiment'] == 0).sum()) / before_game['Sentiment'].count()
        else:
            before_game = team_df[(team_df['Date'] < attendance_df['Date'][index]) & (attendance_df['Date'][(index-1)] <= team_df['Date'])]
            attendance_df['Polarized Sentiment Ratio'][index] = ((before_game['Sentiment'] == 2).sum() + (before_game['Sentiment'] == 0).sum()) / before_game['Sentiment'].count()
    return attendance_df

# %% [markdown]
# Raptors

# %%
raptors_attendance = pd.read_csv('data/attendance/teams/raptors_2018_2019_attendance.csv', index_col=0)

# %%
polar_sentiment_ratio_calc(raptors_attendance, raptors)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#     index                      Date Start (ET)         Visitor/Neutral  PTS  \
# 0       7 2018-10-17 19:30:00+00:00      7:30p     Cleveland Cavaliers  104
# 1      21 2018-10-19 20:00:00+00:00      8:00p          Boston Celtics  101
# 2      26 2018-10-20 19:00:00+00:00      7:00p         Toronto Raptors  117
# 3      40 2018-10-22 19:30:00+00:00      7:30p       Charlotte Hornets  106
# 4      54 2018-10-24 19:30:00+00:00      7:30p  Minnesota Timberwolves  105
# ..    ...                       ...        ...                     ...  ...
# 77   1155 2019-04-01 19:30:00+00:00      7:30p           Orlando Magic  109
# 78   1168 2019-04-03 19:30:00+00:00      7:30p         Toronto Raptors  115
# 79   1179 2019-04-05 19:00:00+00:00      7:00p         Toronto Raptors  111
# 80   1194 2019-04-07 12:00:00+00:00     12:00p              Miami Heat  109
# 81   1213 2019-04-09 20:00:00+00:00      8:00p         Toronto Raptors  120
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0          Toronto Raptors    116  Box Score        NaN    19915    NaN
# 1          Toronto Raptors    113  Box Score        NaN    19800    NaN
# 2       Washington Wizards    113  Box Score        NaN    16185    NaN
# 3          Toronto Raptors    127  Box Score        NaN    19800    NaN
# 4          Toronto Raptors    112  Box Score        NaN    19800    NaN
# ..                     ...    ...        ...        ...      ...    ...
# 77         Toronto Raptors    121  Box Score        NaN    19800    NaN
# 78           Brooklyn Nets    105  Box Score        NaN    17732    NaN
# 79       Charlotte Hornets    113  Box Score        NaN    18684    NaN
# 80         Toronto Raptors    117  Box Score         OT    19800    NaN
# 81  Minnesota Timberwolves    100  Box Score        NaN    16119    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio
# 0      19800          1.000000                   0.672414
# 1      19800          1.000000                   0.687500
# 2      20356          0.795097                   0.516129
# 3      19800          1.000000                   0.545455
# 4      19800          1.000000                   0.620690
# ..       ...               ...                        ...
# 77     19800          1.000000                   0.648148
# 78     17732          1.000000                   0.656250
# 79     19077          0.979399                   0.661290
# 80     19800          1.000000                   0.687500
# 81     18978          0.849352                   0.666667
#
# [82 rows x 14 columns]

# %% [markdown]
# Knicks

# %%
knicks_attendance = pd.read_csv('data/attendance/teams/knicks_2018_2019_attendance.csv', index_col=0)

# %%
polar_sentiment_ratio_calc(knicks_attendance, knicks)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#     index                      Date Start (ET)     Visitor/Neutral  PTS  \
# 0       6 2018-10-17 19:30:00+00:00      7:30p       Atlanta Hawks  107
# 1      17 2018-10-19 19:30:00+00:00      7:30p     New York Knicks  105
# 2      27 2018-10-20 19:30:00+00:00      7:30p      Boston Celtics  103
# 3      41 2018-10-22 20:00:00+00:00      8:00p     New York Knicks  113
# 4      53 2018-10-24 19:30:00+00:00      7:30p     New York Knicks   87
# ..    ...                       ...        ...                 ...  ...
# 77   1165 2019-04-03 19:00:00+00:00      7:00p     New York Knicks  100
# 78   1182 2019-04-05 20:00:00+00:00      8:00p     New York Knicks   96
# 79   1203 2019-04-07 19:30:00+00:00      7:30p  Washington Wizards  110
# 80   1212 2019-04-09 20:00:00+00:00      8:00p     New York Knicks   96
# 81   1224 2019-04-10 20:00:00+00:00      8:00p     Detroit Pistons  115
#
#        Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend. Notes  Capacity  \
# 0   New York Knicks    126  Box Score        NaN    18249   NaN     19812
# 1     Brooklyn Nets    107  Box Score        NaN    17732   NaN     17732
# 2   New York Knicks    101  Box Score        NaN    19427   NaN     19812
# 3   Milwaukee Bucks    124  Box Score        NaN    16228   NaN     17500
# 4        Miami Heat    110  Box Score        NaN    19600   NaN     19600
# ..              ...    ...        ...        ...      ...   ...       ...
# 77    Orlando Magic    114  Box Score        NaN    18846   NaN     18846
# 78  Houston Rockets    120  Box Score        NaN    18055   NaN     18055
# 79  New York Knicks    113  Box Score        NaN    19812   NaN     19812
# 80    Chicago Bulls     86  Box Score        NaN    21350   NaN     20917
# 81  New York Knicks     89  Box Score        NaN    19812   NaN     19812
#
#     Attendance Ratio  Polarized Sentiment Ratio
# 0           0.921108                   0.445946
# 1           1.000000                   0.550000
# 2           0.980567                   0.500000
# 3           0.927314                   0.478261
# 4           1.000000                   0.500000
# ..               ...                        ...
# 77          1.000000                   0.623288
# 78          1.000000                   0.580882
# 79          1.000000                   0.621429
# 80          1.000000                   0.662500
# 81          1.000000                   0.666667
#
# [82 rows x 14 columns]

# %% [markdown]
# Lakers

# %%
lakers_attendance = pd.read_csv('data/attendance/teams/lakers_2018_2019_attendance.csv', index_col=0)

# %%
polar_sentiment_ratio_calc(lakers_attendance, lakers)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#     index                      Date Start (ET)         Visitor/Neutral  PTS  \
# 0      15 2018-10-18 22:30:00+00:00     10:30p      Los Angeles Lakers  119
# 1      34 2018-10-20 22:30:00+00:00     10:30p         Houston Rockets  124
# 2      47 2018-10-22 22:30:00+00:00     10:30p       San Antonio Spurs  143
# 3      59 2018-10-24 22:00:00+00:00     10:00p      Los Angeles Lakers  131
# 4      65 2018-10-25 22:30:00+00:00     10:30p          Denver Nuggets  114
# ..    ...                       ...        ...                     ...  ...
# 77   1160 2019-04-02 20:00:00+00:00      8:00p      Los Angeles Lakers  103
# 78   1178 2019-04-04 22:30:00+00:00     10:30p   Golden State Warriors  108
# 79   1191 2019-04-05 22:30:00+00:00     10:30p      Los Angeles Lakers  122
# 80   1207 2019-04-07 21:30:00+00:00      9:30p               Utah Jazz  109
# 81   1218 2019-04-09 22:30:00+00:00     10:30p  Portland Trail Blazers  104
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0   Portland Trail Blazers    128  Box Score        NaN    19996    NaN
# 1       Los Angeles Lakers    115  Box Score        NaN    18997    NaN
# 2       Los Angeles Lakers    142  Box Score         OT    18997    NaN
# 3             Phoenix Suns    113  Box Score        NaN    18055    NaN
# 4       Los Angeles Lakers    121  Box Score        NaN    18997    NaN
# ..                     ...    ...        ...        ...      ...    ...
# 77   Oklahoma City Thunder    119  Box Score        NaN    18203    NaN
# 78      Los Angeles Lakers     90  Box Score        NaN    18997    NaN
# 79    Los Angeles Clippers    117  Box Score        NaN    17910    NaN
# 80      Los Angeles Lakers    113  Box Score        NaN    18997    NaN
# 81      Los Angeles Lakers    101  Box Score        NaN    18997    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio
# 0      19441           1.00000                   0.614865
# 1      18997           1.00000                   0.591667
# 2      18997           1.00000                   0.573529
# 3      18055           1.00000                   0.580645
# 4      18997           1.00000                   0.631579
# ..       ...               ...                        ...
# 77     18203           1.00000                   0.733681
# 78     18997           1.00000                   0.713821
# 79     19068           0.93927                   0.756410
# 80     18997           1.00000                   0.679121
# 81     18997           1.00000                   0.745652
#
# [82 rows x 14 columns]

# %% [markdown]
# Rockets

# %%
rockets_attendance = pd.read_csv('data/attendance/teams/rockets_2018_2019_attendance.csv', index_col=0)

# %%
polar_sentiment_ratio_calc(rockets_attendance, rockets)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#     index                      Date Start (ET)       Visitor/Neutral  PTS  \
# 0       8 2018-10-17 20:00:00+00:00      8:00p  New Orleans Pelicans  131
# 1      34 2018-10-20 22:30:00+00:00     10:30p       Houston Rockets  124
# 2      38 2018-10-21 21:00:00+00:00      9:00p       Houston Rockets  112
# 3      56 2018-10-24 20:00:00+00:00      8:00p             Utah Jazz  100
# 4      69 2018-10-26 20:00:00+00:00      8:00p  Los Angeles Clippers  133
# ..    ...                       ...        ...                   ...  ...
# 77   1162 2019-04-02 22:00:00+00:00     10:00p       Houston Rockets  130
# 78   1175 2019-04-03 22:30:00+00:00     10:30p       Houston Rockets  135
# 79   1182 2019-04-05 20:00:00+00:00      8:00p       New York Knicks   96
# 80   1200 2019-04-07 19:00:00+00:00      7:00p          Phoenix Suns  113
# 81   1217 2019-04-09 21:30:00+00:00      9:30p       Houston Rockets  111
#
#              Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0         Houston Rockets    112  Box Score        NaN    18055    NaN
# 1      Los Angeles Lakers    115  Box Score        NaN    18997    NaN
# 2    Los Angeles Clippers    115  Box Score        NaN    16149    NaN
# 3         Houston Rockets     89  Box Score        NaN    18055    NaN
# 4         Houston Rockets    113  Box Score        NaN    18055    NaN
# ..                    ...    ...        ...        ...      ...    ...
# 77       Sacramento Kings    105  Box Score        NaN    17583    NaN
# 78   Los Angeles Clippers    103  Box Score        NaN    17593    NaN
# 79        Houston Rockets    120  Box Score        NaN    18055    NaN
# 80        Houston Rockets    149  Box Score        NaN    18055    NaN
# 81  Oklahoma City Thunder    112  Box Score        NaN    18203    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio
# 0      18055          1.000000                   0.467742
# 1      18997          1.000000                   0.600000
# 2      19068          0.846916                   0.549020
# 3      18055          1.000000                   0.348837
# 4      18055          1.000000                   0.400000
# ..       ...               ...                        ...
# 77     17583          1.000000                   0.610487
# 78     19068          0.922645                   0.544944
# 79     18055          1.000000                   0.629630
# 80     18055          1.000000                   0.579909
# 81     18203          1.000000                   0.597101
#
# [82 rows x 14 columns]

# %% [markdown]
# Warriors

# %%
warriors_attendance = pd.read_csv('data/attendance/teams/warriors_2018_2019_attendance.csv', index_col=0)

# %%
polar_sentiment_ratio_calc(warriors_attendance, warriors)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#     index                      Date Start (ET)        Visitor/Neutral  PTS  \
# 0       1 2018-10-16 22:30:00+00:00     10:30p  Oklahoma City Thunder  100
# 1      24 2018-10-19 22:30:00+00:00     10:30p  Golden State Warriors  124
# 2      37 2018-10-21 20:00:00+00:00      8:00p  Golden State Warriors   98
# 3      46 2018-10-22 22:30:00+00:00     10:30p           Phoenix Suns  103
# 4      61 2018-10-24 22:30:00+00:00     10:30p     Washington Wizards  122
# ..    ...                       ...        ...                    ...  ...
# 77   1178 2019-04-04 22:30:00+00:00     10:30p  Golden State Warriors  108
# 78   1190 2019-04-05 22:30:00+00:00     10:30p    Cleveland Cavaliers  114
# 79   1204 2019-04-07 20:30:00+00:00      8:30p   Los Angeles Clippers  104
# 80   1214 2019-04-09 20:00:00+00:00      8:00p  Golden State Warriors  112
# 81   1222 2019-04-10 20:00:00+00:00      8:00p  Golden State Warriors  117
#
#              Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0   Golden State Warriors    108  Box Score        NaN    19596    NaN
# 1               Utah Jazz    123  Box Score        NaN    18306    NaN
# 2          Denver Nuggets    100  Box Score        NaN    19520    NaN
# 3   Golden State Warriors    123  Box Score        NaN    19596    NaN
# 4   Golden State Warriors    144  Box Score        NaN    19596    NaN
# ..                    ...    ...        ...        ...      ...    ...
# 77     Los Angeles Lakers     90  Box Score        NaN    18997    NaN
# 78  Golden State Warriors    120  Box Score        NaN    19596    NaN
# 79  Golden State Warriors    131  Box Score        NaN    19596    NaN
# 80   New Orleans Pelicans    103  Box Score        NaN    17090    NaN
# 81      Memphis Grizzlies    132  Box Score        NaN    17794    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio
# 0      18064               1.0                   0.625641
# 1      18306               1.0                   0.662162
# 2      19520               1.0                   0.645161
# 3      18064               1.0                   0.571429
# 4      18064               1.0                   0.725000
# ..       ...               ...                        ...
# 77     18997               1.0                   0.722749
# 78     18064               1.0                   0.714976
# 79     18064               1.0                   0.654378
# 80     16867               1.0                   0.737143
# 81     17794               1.0                   0.673077
#
# [82 rows x 14 columns]

# %% [markdown]
# #### Plots

# %%
plt.subplots(2,3, figsize=(15,10))

plt.subplot(2,3,1)
plt.scatter(raptors_attendance['Polarized Sentiment Ratio'], raptors_attendance['Attendance Ratio'])
plt.title('Raptors')

plt.subplot(2,3,2)
plt.scatter(knicks_attendance['Polarized Sentiment Ratio'], knicks_attendance['Attendance Ratio'])
plt.title('Knicks')

plt.subplot(2,3,3)
plt.scatter(lakers_attendance['Polarized Sentiment Ratio'], lakers_attendance['Attendance Ratio'])
plt.title('Lakers')

plt.subplot(2,3,4)
plt.scatter(rockets_attendance['Polarized Sentiment Ratio'], rockets_attendance['Attendance Ratio'])
plt.title('Rockets')

plt.subplot(2,3,5)
plt.scatter(warriors_attendance['Polarized Sentiment Ratio'], warriors_attendance['Attendance Ratio'])
plt.title('Warriors')

plt.show()

# %%
plt.subplots(2,3, figsize=(20,10))

plt.subplot(2,3,1)
plt.plot(raptors_attendance['Date'], raptors_attendance['Polarized Sentiment Ratio'])
plt.title('Raptors')

plt.subplot(2,3,2)
plt.plot(knicks_attendance['Date'], knicks_attendance['Polarized Sentiment Ratio'])
plt.title('Knicks')

plt.subplot(2,3,3)
plt.plot(lakers_attendance['Date'], lakers_attendance['Polarized Sentiment Ratio'])
plt.title('Lakers')

plt.subplot(2,3,4)
plt.plot(rockets_attendance['Date'], rockets_attendance['Polarized Sentiment Ratio'])
plt.title('Rockets')

plt.subplot(2,3,5)
plt.plot(warriors_attendance['Date'], warriors_attendance['Polarized Sentiment Ratio'])
plt.title('Warriors')

plt.show()
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.subplots(2,3, figsize=(20,10))

plt.subplot(2,3,1)
plt.plot(raptors_attendance['Date'], raptors_attendance['Attendance Ratio'], marker='.')
plt.title('Raptors')

plt.subplot(2,3,2)
plt.plot(knicks_attendance['Date'], knicks_attendance['Attendance Ratio'], marker='.')
plt.title('Knicks')

plt.subplot(2,3,3)
plt.plot(lakers_attendance['Date'], lakers_attendance['Attendance Ratio'], marker='.')
plt.title('Lakers')

plt.subplot(2,3,4)
plt.plot(rockets_attendance['Date'], rockets_attendance['Attendance Ratio'], marker='.')
plt.title('Rockets')

plt.subplot(2,3,5)
plt.plot(warriors_attendance['Date'], warriors_attendance['Attendance Ratio'], marker='.')
plt.title('Warriors')

plt.show()

# %% [markdown]
# #### Linear Regression Models

# %%
#function to run linear regression
def regression_modeler_polar_sent(attendance_df):
    X = attendance_df['Polarized Sentiment Ratio']
    y = attendance_df['Attendance Ratio']
    
    X_withconstant = sm.add_constant(X)
    
    linreg = sm.OLS(y,X_withconstant)
    linreg_results = linreg.fit()
    return linreg_results.summary()

# %%
regression_modeler_polar_sent(raptors_attendance)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     4.280
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):             0.0418
# Time:                        12:59:48   Log-Likelihood:                 126.06
# No. Observations:                  82   AIC:                            -248.1
# Df Residuals:                      80   BIC:                            -243.3
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.9221      0.028     33.385      0.000       0.867       0.977
# Polarized Sentiment Ratio     0.0960      0.046      2.069      0.042       0.004       0.188
# ==============================================================================
# Omnibus:                       51.593   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.544
# Skew:                          -2.287   Prob(JB):                     8.23e-31
# Kurtosis:                       7.431   Cond. No.                         10.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_polar_sent(knicks_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.734
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.192
# Time:                        12:59:48   Log-Likelihood:                 92.515
# No. Observations:                  82   AIC:                            -181.0
# Df Residuals:                      80   BIC:                            -176.2
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.8930      0.039     22.912      0.000       0.815       0.971
# Polarized Sentiment Ratio     0.0934      0.071      1.317      0.192      -0.048       0.235
# ==============================================================================
# Omnibus:                       36.185   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.126
# Skew:                          -1.765   Prob(JB):                     4.38e-15
# Kurtosis:                       5.626   Cond. No.                         10.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_polar_sent(lakers_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.1332
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.716
# Time:                        12:59:48   Log-Likelihood:                 254.09
# No. Observations:                  82   AIC:                            -504.2
# Df Residuals:                      80   BIC:                            -499.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.9952      0.007    134.567      0.000       0.981       1.010
# Polarized Sentiment Ratio     0.0044      0.012      0.365      0.716      -0.020       0.028
# ==============================================================================
# Omnibus:                      125.484   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3048.293
# Skew:                          -5.360   Prob(JB):                         0.00
# Kurtosis:                      30.879   Cond. No.                         13.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_polar_sent(rockets_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                  0.006322
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.937
# Time:                        12:59:48   Log-Likelihood:                 115.68
# No. Observations:                  82   AIC:                            -227.4
# Df Residuals:                      80   BIC:                            -222.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.9761      0.030     32.770      0.000       0.917       1.035
# Polarized Sentiment Ratio    -0.0048      0.060     -0.080      0.937      -0.124       0.114
# ==============================================================================
# Omnibus:                       52.963   Durbin-Watson:                   2.290
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.856
# Skew:                          -2.337   Prob(JB):                     1.29e-32
# Kurtosis:                       7.597   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_polar_sent(warriors_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.227
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.271
# Time:                        12:59:48   Log-Likelihood:                 235.13
# No. Observations:                  82   AIC:                            -466.3
# Df Residuals:                      80   BIC:                            -461.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.9853      0.011     93.788      0.000       0.964       1.006
# Polarized Sentiment Ratio     0.0194      0.018      1.108      0.271      -0.015       0.054
# ==============================================================================
# Omnibus:                      103.805   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1287.930
# Skew:                          -4.286   Prob(JB):                    2.14e-280
# Kurtosis:                      20.421   Cond. No.                         15.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Positive Sentiment Effect

# %%
#function to find positive sentiment (positive/total tweets) prior to games
def pos_sentiment_ratio_calc(attendance_df, team_df):
    attendance_df['Positive Sentiment Ratio'] = np.nan
    for index, row in attendance_df.iterrows():
        if index == 0:
            before_game = team_df[team_df['Date'] < attendance_df['Date'][index]]
            attendance_df['Positive Sentiment Ratio'][index] = ((before_game['Sentiment'] == 2).sum()) / before_game['Sentiment'].count()
        else:
            before_game = team_df[(team_df['Date'] < attendance_df['Date'][index]) & (attendance_df['Date'][(index-1)] <= team_df['Date'])]
            attendance_df['Positive Sentiment Ratio'][index] = ((before_game['Sentiment'] == 2).sum()) / before_game['Sentiment'].count()
    return attendance_df

# %% [markdown]
# Raptors

# %%
pos_sentiment_ratio_calc(raptors_attendance, raptors)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)         Visitor/Neutral  PTS  \
# 0       7 2018-10-17 19:30:00+00:00      7:30p     Cleveland Cavaliers  104
# 1      21 2018-10-19 20:00:00+00:00      8:00p          Boston Celtics  101
# 2      26 2018-10-20 19:00:00+00:00      7:00p         Toronto Raptors  117
# 3      40 2018-10-22 19:30:00+00:00      7:30p       Charlotte Hornets  106
# 4      54 2018-10-24 19:30:00+00:00      7:30p  Minnesota Timberwolves  105
# ..    ...                       ...        ...                     ...  ...
# 77   1155 2019-04-01 19:30:00+00:00      7:30p           Orlando Magic  109
# 78   1168 2019-04-03 19:30:00+00:00      7:30p         Toronto Raptors  115
# 79   1179 2019-04-05 19:00:00+00:00      7:00p         Toronto Raptors  111
# 80   1194 2019-04-07 12:00:00+00:00     12:00p              Miami Heat  109
# 81   1213 2019-04-09 20:00:00+00:00      8:00p         Toronto Raptors  120
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0          Toronto Raptors    116  Box Score        NaN    19915    NaN
# 1          Toronto Raptors    113  Box Score        NaN    19800    NaN
# 2       Washington Wizards    113  Box Score        NaN    16185    NaN
# 3          Toronto Raptors    127  Box Score        NaN    19800    NaN
# 4          Toronto Raptors    112  Box Score        NaN    19800    NaN
# ..                     ...    ...        ...        ...      ...    ...
# 77         Toronto Raptors    121  Box Score        NaN    19800    NaN
# 78           Brooklyn Nets    105  Box Score        NaN    17732    NaN
# 79       Charlotte Hornets    113  Box Score        NaN    18684    NaN
# 80         Toronto Raptors    117  Box Score         OT    19800    NaN
# 81  Minnesota Timberwolves    100  Box Score        NaN    16119    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      19800          1.000000                   0.672414
# 1      19800          1.000000                   0.687500
# 2      20356          0.795097                   0.516129
# 3      19800          1.000000                   0.545455
# 4      19800          1.000000                   0.620690
# ..       ...               ...                        ...
# 77     19800          1.000000                   0.648148
# 78     17732          1.000000                   0.656250
# 79     19077          0.979399                   0.661290
# 80     19800          1.000000                   0.687500
# 81     18978          0.849352                   0.666667
#
#     Positive Sentiment Ratio
# 0                   0.413793
# 1                   0.343750
# 2                   0.322581
# 3                   0.181818
# 4                   0.379310
# ..                       ...
# 77                  0.157407
# 78                  0.265625
# 79                  0.137097
# 80                  0.203125
# 81                  0.195402
#
# [82 rows x 15 columns]

# %% [markdown]
# Knicks

# %%
pos_sentiment_ratio_calc(knicks_attendance, knicks)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)     Visitor/Neutral  PTS  \
# 0       6 2018-10-17 19:30:00+00:00      7:30p       Atlanta Hawks  107
# 1      17 2018-10-19 19:30:00+00:00      7:30p     New York Knicks  105
# 2      27 2018-10-20 19:30:00+00:00      7:30p      Boston Celtics  103
# 3      41 2018-10-22 20:00:00+00:00      8:00p     New York Knicks  113
# 4      53 2018-10-24 19:30:00+00:00      7:30p     New York Knicks   87
# ..    ...                       ...        ...                 ...  ...
# 77   1165 2019-04-03 19:00:00+00:00      7:00p     New York Knicks  100
# 78   1182 2019-04-05 20:00:00+00:00      8:00p     New York Knicks   96
# 79   1203 2019-04-07 19:30:00+00:00      7:30p  Washington Wizards  110
# 80   1212 2019-04-09 20:00:00+00:00      8:00p     New York Knicks   96
# 81   1224 2019-04-10 20:00:00+00:00      8:00p     Detroit Pistons  115
#
#        Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend. Notes  Capacity  \
# 0   New York Knicks    126  Box Score        NaN    18249   NaN     19812
# 1     Brooklyn Nets    107  Box Score        NaN    17732   NaN     17732
# 2   New York Knicks    101  Box Score        NaN    19427   NaN     19812
# 3   Milwaukee Bucks    124  Box Score        NaN    16228   NaN     17500
# 4        Miami Heat    110  Box Score        NaN    19600   NaN     19600
# ..              ...    ...        ...        ...      ...   ...       ...
# 77    Orlando Magic    114  Box Score        NaN    18846   NaN     18846
# 78  Houston Rockets    120  Box Score        NaN    18055   NaN     18055
# 79  New York Knicks    113  Box Score        NaN    19812   NaN     19812
# 80    Chicago Bulls     86  Box Score        NaN    21350   NaN     20917
# 81  New York Knicks     89  Box Score        NaN    19812   NaN     19812
#
#     Attendance Ratio  Polarized Sentiment Ratio  Positive Sentiment Ratio
# 0           0.921108                   0.445946                  0.162162
# 1           1.000000                   0.550000                  0.300000
# 2           0.980567                   0.500000                  0.071429
# 3           0.927314                   0.478261                  0.173913
# 4           1.000000                   0.500000                  0.062500
# ..               ...                        ...                       ...
# 77          1.000000                   0.623288                  0.150685
# 78          1.000000                   0.580882                  0.102941
# 79          1.000000                   0.621429                  0.114286
# 80          1.000000                   0.662500                  0.118750
# 81          1.000000                   0.666667                  0.207547
#
# [82 rows x 15 columns]

# %% [markdown]
# Lakers

# %%
pos_sentiment_ratio_calc(lakers_attendance, lakers)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)         Visitor/Neutral  PTS  \
# 0      15 2018-10-18 22:30:00+00:00     10:30p      Los Angeles Lakers  119
# 1      34 2018-10-20 22:30:00+00:00     10:30p         Houston Rockets  124
# 2      47 2018-10-22 22:30:00+00:00     10:30p       San Antonio Spurs  143
# 3      59 2018-10-24 22:00:00+00:00     10:00p      Los Angeles Lakers  131
# 4      65 2018-10-25 22:30:00+00:00     10:30p          Denver Nuggets  114
# ..    ...                       ...        ...                     ...  ...
# 77   1160 2019-04-02 20:00:00+00:00      8:00p      Los Angeles Lakers  103
# 78   1178 2019-04-04 22:30:00+00:00     10:30p   Golden State Warriors  108
# 79   1191 2019-04-05 22:30:00+00:00     10:30p      Los Angeles Lakers  122
# 80   1207 2019-04-07 21:30:00+00:00      9:30p               Utah Jazz  109
# 81   1218 2019-04-09 22:30:00+00:00     10:30p  Portland Trail Blazers  104
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0   Portland Trail Blazers    128  Box Score        NaN    19996    NaN
# 1       Los Angeles Lakers    115  Box Score        NaN    18997    NaN
# 2       Los Angeles Lakers    142  Box Score         OT    18997    NaN
# 3             Phoenix Suns    113  Box Score        NaN    18055    NaN
# 4       Los Angeles Lakers    121  Box Score        NaN    18997    NaN
# ..                     ...    ...        ...        ...      ...    ...
# 77   Oklahoma City Thunder    119  Box Score        NaN    18203    NaN
# 78      Los Angeles Lakers     90  Box Score        NaN    18997    NaN
# 79    Los Angeles Clippers    117  Box Score        NaN    17910    NaN
# 80      Los Angeles Lakers    113  Box Score        NaN    18997    NaN
# 81      Los Angeles Lakers    101  Box Score        NaN    18997    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      19441           1.00000                   0.614865
# 1      18997           1.00000                   0.591667
# 2      18997           1.00000                   0.573529
# 3      18055           1.00000                   0.580645
# 4      18997           1.00000                   0.631579
# ..       ...               ...                        ...
# 77     18203           1.00000                   0.733681
# 78     18997           1.00000                   0.713821
# 79     19068           0.93927                   0.756410
# 80     18997           1.00000                   0.679121
# 81     18997           1.00000                   0.745652
#
#     Positive Sentiment Ratio
# 0                   0.199324
# 1                   0.208333
# 2                   0.213235
# 3                   0.209677
# 4                   0.333333
# ..                       ...
# 77                  0.185379
# 78                  0.126829
# 79                  0.179487
# 80                  0.178022
# 81                  0.132609
#
# [82 rows x 15 columns]

# %% [markdown]
# Rockets

# %%
pos_sentiment_ratio_calc(rockets_attendance, rockets)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)       Visitor/Neutral  PTS  \
# 0       8 2018-10-17 20:00:00+00:00      8:00p  New Orleans Pelicans  131
# 1      34 2018-10-20 22:30:00+00:00     10:30p       Houston Rockets  124
# 2      38 2018-10-21 21:00:00+00:00      9:00p       Houston Rockets  112
# 3      56 2018-10-24 20:00:00+00:00      8:00p             Utah Jazz  100
# 4      69 2018-10-26 20:00:00+00:00      8:00p  Los Angeles Clippers  133
# ..    ...                       ...        ...                   ...  ...
# 77   1162 2019-04-02 22:00:00+00:00     10:00p       Houston Rockets  130
# 78   1175 2019-04-03 22:30:00+00:00     10:30p       Houston Rockets  135
# 79   1182 2019-04-05 20:00:00+00:00      8:00p       New York Knicks   96
# 80   1200 2019-04-07 19:00:00+00:00      7:00p          Phoenix Suns  113
# 81   1217 2019-04-09 21:30:00+00:00      9:30p       Houston Rockets  111
#
#              Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0         Houston Rockets    112  Box Score        NaN    18055    NaN
# 1      Los Angeles Lakers    115  Box Score        NaN    18997    NaN
# 2    Los Angeles Clippers    115  Box Score        NaN    16149    NaN
# 3         Houston Rockets     89  Box Score        NaN    18055    NaN
# 4         Houston Rockets    113  Box Score        NaN    18055    NaN
# ..                    ...    ...        ...        ...      ...    ...
# 77       Sacramento Kings    105  Box Score        NaN    17583    NaN
# 78   Los Angeles Clippers    103  Box Score        NaN    17593    NaN
# 79        Houston Rockets    120  Box Score        NaN    18055    NaN
# 80        Houston Rockets    149  Box Score        NaN    18055    NaN
# 81  Oklahoma City Thunder    112  Box Score        NaN    18203    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      18055          1.000000                   0.467742
# 1      18997          1.000000                   0.600000
# 2      19068          0.846916                   0.549020
# 3      18055          1.000000                   0.348837
# 4      18055          1.000000                   0.400000
# ..       ...               ...                        ...
# 77     17583          1.000000                   0.610487
# 78     19068          0.922645                   0.544944
# 79     18055          1.000000                   0.629630
# 80     18055          1.000000                   0.579909
# 81     18203          1.000000                   0.597101
#
#     Positive Sentiment Ratio
# 0                   0.209677
# 1                   0.100000
# 2                   0.039216
# 3                   0.116279
# 4                   0.266667
# ..                       ...
# 77                  0.157303
# 78                  0.117978
# 79                  0.170370
# 80                  0.191781
# 81                  0.171014
#
# [82 rows x 15 columns]

# %% [markdown]
# Warriors

# %%
pos_sentiment_ratio_calc(warriors_attendance, warriors)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)        Visitor/Neutral  PTS  \
# 0       1 2018-10-16 22:30:00+00:00     10:30p  Oklahoma City Thunder  100
# 1      24 2018-10-19 22:30:00+00:00     10:30p  Golden State Warriors  124
# 2      37 2018-10-21 20:00:00+00:00      8:00p  Golden State Warriors   98
# 3      46 2018-10-22 22:30:00+00:00     10:30p           Phoenix Suns  103
# 4      61 2018-10-24 22:30:00+00:00     10:30p     Washington Wizards  122
# ..    ...                       ...        ...                    ...  ...
# 77   1178 2019-04-04 22:30:00+00:00     10:30p  Golden State Warriors  108
# 78   1190 2019-04-05 22:30:00+00:00     10:30p    Cleveland Cavaliers  114
# 79   1204 2019-04-07 20:30:00+00:00      8:30p   Los Angeles Clippers  104
# 80   1214 2019-04-09 20:00:00+00:00      8:00p  Golden State Warriors  112
# 81   1222 2019-04-10 20:00:00+00:00      8:00p  Golden State Warriors  117
#
#              Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0   Golden State Warriors    108  Box Score        NaN    19596    NaN
# 1               Utah Jazz    123  Box Score        NaN    18306    NaN
# 2          Denver Nuggets    100  Box Score        NaN    19520    NaN
# 3   Golden State Warriors    123  Box Score        NaN    19596    NaN
# 4   Golden State Warriors    144  Box Score        NaN    19596    NaN
# ..                    ...    ...        ...        ...      ...    ...
# 77     Los Angeles Lakers     90  Box Score        NaN    18997    NaN
# 78  Golden State Warriors    120  Box Score        NaN    19596    NaN
# 79  Golden State Warriors    131  Box Score        NaN    19596    NaN
# 80   New Orleans Pelicans    103  Box Score        NaN    17090    NaN
# 81      Memphis Grizzlies    132  Box Score        NaN    17794    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      18064               1.0                   0.625641
# 1      18306               1.0                   0.662162
# 2      19520               1.0                   0.645161
# 3      18064               1.0                   0.571429
# 4      18064               1.0                   0.725000
# ..       ...               ...                        ...
# 77     18997               1.0                   0.722749
# 78     18064               1.0                   0.714976
# 79     18064               1.0                   0.654378
# 80     16867               1.0                   0.737143
# 81     17794               1.0                   0.673077
#
#     Positive Sentiment Ratio
# 0                   0.266667
# 1                   0.229730
# 2                   0.193548
# 3                   0.171429
# 4                   0.325000
# ..                       ...
# 77                  0.191943
# 78                  0.202899
# 79                  0.253456
# 80                  0.228571
# 81                  0.230769
#
# [82 rows x 15 columns]

# %% [markdown]
# #### Plots

# %%
plt.subplots(2,3, figsize=(15,10))

plt.subplot(2,3,1)
plt.scatter(raptors_attendance['Positive Sentiment Ratio'], raptors_attendance['Attendance Ratio'])
plt.title('Raptors')

plt.subplot(2,3,2)
plt.scatter(knicks_attendance['Positive Sentiment Ratio'], knicks_attendance['Attendance Ratio'])
plt.title('Knicks')

plt.subplot(2,3,3)
plt.scatter(lakers_attendance['Positive Sentiment Ratio'], lakers_attendance['Attendance Ratio'])
plt.title('Lakers')

plt.subplot(2,3,4)
plt.scatter(rockets_attendance['Positive Sentiment Ratio'], rockets_attendance['Attendance Ratio'])
plt.title('Rockets')

plt.subplot(2,3,5)
plt.scatter(warriors_attendance['Positive Sentiment Ratio'], warriors_attendance['Attendance Ratio'])
plt.title('Warriors')

plt.show()

# %%
plt.subplots(2,3, figsize=(15,10))

plt.subplot(2,3,1)
plt.plot(raptors_attendance['Date'], raptors_attendance['Positive Sentiment Ratio'])
plt.title('Raptors')

plt.subplot(2,3,2)
plt.plot(knicks_attendance['Date'], knicks_attendance['Positive Sentiment Ratio'])
plt.title('Knicks')

plt.subplot(2,3,3)
plt.plot(lakers_attendance['Date'], lakers_attendance['Positive Sentiment Ratio'])
plt.title('Lakers')

plt.subplot(2,3,4)
plt.plot(rockets_attendance['Date'], rockets_attendance['Positive Sentiment Ratio'])
plt.title('Rockets')

plt.subplot(2,3,5)
plt.plot(warriors_attendance['Date'], warriors_attendance['Positive Sentiment Ratio'])
plt.title('Warriors')

plt.show()

# %%
plt.subplots(2,3, figsize=(20,10))

plt.subplot(2,3,1)
plt.plot(raptors_attendance['Date'], raptors_attendance['Attendance Ratio'], marker='.')
plt.title('Raptors')

plt.subplot(2,3,2)
plt.plot(knicks_attendance['Date'], knicks_attendance['Attendance Ratio'], marker='.')
plt.title('Knicks')

plt.subplot(2,3,3)
plt.plot(lakers_attendance['Date'], lakers_attendance['Attendance Ratio'], marker='.')
plt.title('Lakers')

plt.subplot(2,3,4)
plt.plot(rockets_attendance['Date'], rockets_attendance['Attendance Ratio'], marker='.')
plt.title('Rockets')

plt.subplot(2,3,5)
plt.plot(warriors_attendance['Date'], warriors_attendance['Attendance Ratio'], marker='.')
plt.title('Warriors')

plt.show()

# %% [markdown]
# #### Linear Regression Models

# %%
#function to run linear regression
def regression_modeler_pos_sent(attendance_df):
    X = attendance_df['Positive Sentiment Ratio']
    y = attendance_df['Attendance Ratio']
    
    X_withconstant = sm.add_constant(X)
    
    linreg = sm.OLS(y,X_withconstant)
    linreg_results = linreg.fit()
    return linreg_results.summary()

# %%
regression_modeler_pos_sent(raptors_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9591
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.330
# Time:                        12:59:51   Log-Likelihood:                 124.41
# No. Observations:                  82   AIC:                            -244.8
# Df Residuals:                      80   BIC:                            -240.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9650      0.015     66.452      0.000       0.936       0.994
# Positive Sentiment Ratio     0.0491      0.050      0.979      0.330      -0.051       0.149
# ==============================================================================
# Omnibus:                       56.428   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.319
# Skew:                          -2.469   Prob(JB):                     1.71e-37
# Kurtosis:                       8.017   Cond. No.                         9.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_pos_sent(knicks_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.09592
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.758
# Time:                        12:59:51   Log-Likelihood:                 91.685
# No. Observations:                  82   AIC:                            -179.4
# Df Residuals:                      80   BIC:                            -174.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9470      0.016     60.555      0.000       0.916       0.978
# Positive Sentiment Ratio    -0.0287      0.093     -0.310      0.758      -0.213       0.156
# ==============================================================================
# Omnibus:                       37.896   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.679
# Skew:                          -1.832   Prob(JB):                     2.72e-16
# Kurtosis:                       5.748   Cond. No.                         10.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_pos_sent(lakers_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                   0.05106
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.822
# Time:                        12:59:51   Log-Likelihood:                 254.04
# No. Observations:                  82   AIC:                            -504.1
# Df Residuals:                      80   BIC:                            -499.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9987      0.004    257.425      0.000       0.991       1.006
# Positive Sentiment Ratio    -0.0039      0.017     -0.226      0.822      -0.038       0.030
# ==============================================================================
# Omnibus:                      125.795   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3085.880
# Skew:                          -5.377   Prob(JB):                         0.00
# Kurtosis:                      31.063   Cond. No.                         14.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_pos_sent(rockets_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.1374
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.712
# Time:                        12:59:51   Log-Likelihood:                 115.75
# No. Observations:                  82   AIC:                            -227.5
# Df Residuals:                      80   BIC:                            -222.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9680      0.017     57.521      0.000       0.935       1.002
# Positive Sentiment Ratio     0.0306      0.083      0.371      0.712      -0.134       0.195
# ==============================================================================
# Omnibus:                       52.745   Durbin-Watson:                   2.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              145.501
# Skew:                          -2.329   Prob(JB):                     2.54e-32
# Kurtosis:                       7.570   Cond. No.                         13.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_pos_sent(warriors_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                   0.03426
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.854
# Time:                        12:59:52   Log-Likelihood:                 234.53
# No. Observations:                  82   AIC:                            -465.1
# Df Residuals:                      80   BIC:                            -460.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9978      0.005    187.607      0.000       0.987       1.008
# Positive Sentiment Ratio    -0.0038      0.021     -0.185      0.854      -0.045       0.037
# ==============================================================================
# Omnibus:                      106.821   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1443.013
# Skew:                          -4.431   Prob(JB):                         0.00
# Kurtosis:                      21.542   Cond. No.                         14.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Negative Sentiment Effect

# %%
#function to find negative sentiment (positive/total tweets) prior to games
def neg_sentiment_ratio_calc(attendance_df, team_df):
    attendance_df['Negative Sentiment Ratio'] = np.nan
    for index, row in attendance_df.iterrows():
        if index == 0:
            before_game = team_df[team_df['Date'] < attendance_df['Date'][index]]
            attendance_df['Negative Sentiment Ratio'][index] = ((before_game['Sentiment'] == 0).sum()) / before_game['Sentiment'].count()
        else:
            before_game = team_df[(team_df['Date'] < attendance_df['Date'][index]) & (attendance_df['Date'][(index-1)] <= team_df['Date'])]
            attendance_df['Negative Sentiment Ratio'][index] = ((before_game['Sentiment'] == 0).sum()) / before_game['Sentiment'].count()
    return attendance_df

# %% [markdown]
# Raptors

# %%
neg_sentiment_ratio_calc(raptors_attendance, raptors)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)         Visitor/Neutral  PTS  \
# 0       7 2018-10-17 19:30:00+00:00      7:30p     Cleveland Cavaliers  104
# 1      21 2018-10-19 20:00:00+00:00      8:00p          Boston Celtics  101
# 2      26 2018-10-20 19:00:00+00:00      7:00p         Toronto Raptors  117
# 3      40 2018-10-22 19:30:00+00:00      7:30p       Charlotte Hornets  106
# 4      54 2018-10-24 19:30:00+00:00      7:30p  Minnesota Timberwolves  105
# ..    ...                       ...        ...                     ...  ...
# 77   1155 2019-04-01 19:30:00+00:00      7:30p           Orlando Magic  109
# 78   1168 2019-04-03 19:30:00+00:00      7:30p         Toronto Raptors  115
# 79   1179 2019-04-05 19:00:00+00:00      7:00p         Toronto Raptors  111
# 80   1194 2019-04-07 12:00:00+00:00     12:00p              Miami Heat  109
# 81   1213 2019-04-09 20:00:00+00:00      8:00p         Toronto Raptors  120
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0          Toronto Raptors    116  Box Score        NaN    19915    NaN
# 1          Toronto Raptors    113  Box Score        NaN    19800    NaN
# 2       Washington Wizards    113  Box Score        NaN    16185    NaN
# 3          Toronto Raptors    127  Box Score        NaN    19800    NaN
# 4          Toronto Raptors    112  Box Score        NaN    19800    NaN
# ..                     ...    ...        ...        ...      ...    ...
# 77         Toronto Raptors    121  Box Score        NaN    19800    NaN
# 78           Brooklyn Nets    105  Box Score        NaN    17732    NaN
# 79       Charlotte Hornets    113  Box Score        NaN    18684    NaN
# 80         Toronto Raptors    117  Box Score         OT    19800    NaN
# 81  Minnesota Timberwolves    100  Box Score        NaN    16119    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      19800          1.000000                   0.672414
# 1      19800          1.000000                   0.687500
# 2      20356          0.795097                   0.516129
# 3      19800          1.000000                   0.545455
# 4      19800          1.000000                   0.620690
# ..       ...               ...                        ...
# 77     19800          1.000000                   0.648148
# 78     17732          1.000000                   0.656250
# 79     19077          0.979399                   0.661290
# 80     19800          1.000000                   0.687500
# 81     18978          0.849352                   0.666667
#
#     Positive Sentiment Ratio  Negative Sentiment Ratio
# 0                   0.413793                  0.258621
# 1                   0.343750                  0.343750
# 2                   0.322581                  0.193548
# 3                   0.181818                  0.363636
# 4                   0.379310                  0.241379
# ..                       ...                       ...
# 77                  0.157407                  0.490741
# 78                  0.265625                  0.390625
# 79                  0.137097                  0.524194
# 80                  0.203125                  0.484375
# 81                  0.195402                  0.471264
#
# [82 rows x 16 columns]

# %% [markdown]
# Knicks

# %%
neg_sentiment_ratio_calc(knicks_attendance, knicks)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)     Visitor/Neutral  PTS  \
# 0       6 2018-10-17 19:30:00+00:00      7:30p       Atlanta Hawks  107
# 1      17 2018-10-19 19:30:00+00:00      7:30p     New York Knicks  105
# 2      27 2018-10-20 19:30:00+00:00      7:30p      Boston Celtics  103
# 3      41 2018-10-22 20:00:00+00:00      8:00p     New York Knicks  113
# 4      53 2018-10-24 19:30:00+00:00      7:30p     New York Knicks   87
# ..    ...                       ...        ...                 ...  ...
# 77   1165 2019-04-03 19:00:00+00:00      7:00p     New York Knicks  100
# 78   1182 2019-04-05 20:00:00+00:00      8:00p     New York Knicks   96
# 79   1203 2019-04-07 19:30:00+00:00      7:30p  Washington Wizards  110
# 80   1212 2019-04-09 20:00:00+00:00      8:00p     New York Knicks   96
# 81   1224 2019-04-10 20:00:00+00:00      8:00p     Detroit Pistons  115
#
#        Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend. Notes  Capacity  \
# 0   New York Knicks    126  Box Score        NaN    18249   NaN     19812
# 1     Brooklyn Nets    107  Box Score        NaN    17732   NaN     17732
# 2   New York Knicks    101  Box Score        NaN    19427   NaN     19812
# 3   Milwaukee Bucks    124  Box Score        NaN    16228   NaN     17500
# 4        Miami Heat    110  Box Score        NaN    19600   NaN     19600
# ..              ...    ...        ...        ...      ...   ...       ...
# 77    Orlando Magic    114  Box Score        NaN    18846   NaN     18846
# 78  Houston Rockets    120  Box Score        NaN    18055   NaN     18055
# 79  New York Knicks    113  Box Score        NaN    19812   NaN     19812
# 80    Chicago Bulls     86  Box Score        NaN    21350   NaN     20917
# 81  New York Knicks     89  Box Score        NaN    19812   NaN     19812
#
#     Attendance Ratio  Polarized Sentiment Ratio  Positive Sentiment Ratio  \
# 0           0.921108                   0.445946                  0.162162
# 1           1.000000                   0.550000                  0.300000
# 2           0.980567                   0.500000                  0.071429
# 3           0.927314                   0.478261                  0.173913
# 4           1.000000                   0.500000                  0.062500
# ..               ...                        ...                       ...
# 77          1.000000                   0.623288                  0.150685
# 78          1.000000                   0.580882                  0.102941
# 79          1.000000                   0.621429                  0.114286
# 80          1.000000                   0.662500                  0.118750
# 81          1.000000                   0.666667                  0.207547
#
#     Negative Sentiment Ratio
# 0                   0.283784
# 1                   0.250000
# 2                   0.428571
# 3                   0.304348
# 4                   0.437500
# ..                       ...
# 77                  0.472603
# 78                  0.477941
# 79                  0.507143
# 80                  0.543750
# 81                  0.459119
#
# [82 rows x 16 columns]

# %% [markdown]
# Lakers

# %%
neg_sentiment_ratio_calc(lakers_attendance, lakers)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)         Visitor/Neutral  PTS  \
# 0      15 2018-10-18 22:30:00+00:00     10:30p      Los Angeles Lakers  119
# 1      34 2018-10-20 22:30:00+00:00     10:30p         Houston Rockets  124
# 2      47 2018-10-22 22:30:00+00:00     10:30p       San Antonio Spurs  143
# 3      59 2018-10-24 22:00:00+00:00     10:00p      Los Angeles Lakers  131
# 4      65 2018-10-25 22:30:00+00:00     10:30p          Denver Nuggets  114
# ..    ...                       ...        ...                     ...  ...
# 77   1160 2019-04-02 20:00:00+00:00      8:00p      Los Angeles Lakers  103
# 78   1178 2019-04-04 22:30:00+00:00     10:30p   Golden State Warriors  108
# 79   1191 2019-04-05 22:30:00+00:00     10:30p      Los Angeles Lakers  122
# 80   1207 2019-04-07 21:30:00+00:00      9:30p               Utah Jazz  109
# 81   1218 2019-04-09 22:30:00+00:00     10:30p  Portland Trail Blazers  104
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0   Portland Trail Blazers    128  Box Score        NaN    19996    NaN
# 1       Los Angeles Lakers    115  Box Score        NaN    18997    NaN
# 2       Los Angeles Lakers    142  Box Score         OT    18997    NaN
# 3             Phoenix Suns    113  Box Score        NaN    18055    NaN
# 4       Los Angeles Lakers    121  Box Score        NaN    18997    NaN
# ..                     ...    ...        ...        ...      ...    ...
# 77   Oklahoma City Thunder    119  Box Score        NaN    18203    NaN
# 78      Los Angeles Lakers     90  Box Score        NaN    18997    NaN
# 79    Los Angeles Clippers    117  Box Score        NaN    17910    NaN
# 80      Los Angeles Lakers    113  Box Score        NaN    18997    NaN
# 81      Los Angeles Lakers    101  Box Score        NaN    18997    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      19441           1.00000                   0.614865
# 1      18997           1.00000                   0.591667
# 2      18997           1.00000                   0.573529
# 3      18055           1.00000                   0.580645
# 4      18997           1.00000                   0.631579
# ..       ...               ...                        ...
# 77     18203           1.00000                   0.733681
# 78     18997           1.00000                   0.713821
# 79     19068           0.93927                   0.756410
# 80     18997           1.00000                   0.679121
# 81     18997           1.00000                   0.745652
#
#     Positive Sentiment Ratio  Negative Sentiment Ratio
# 0                   0.199324                  0.415541
# 1                   0.208333                  0.383333
# 2                   0.213235                  0.360294
# 3                   0.209677                  0.370968
# 4                   0.333333                  0.298246
# ..                       ...                       ...
# 77                  0.185379                  0.548303
# 78                  0.126829                  0.586992
# 79                  0.179487                  0.576923
# 80                  0.178022                  0.501099
# 81                  0.132609                  0.613043
#
# [82 rows x 16 columns]

# %% [markdown]
# Rockets

# %%
neg_sentiment_ratio_calc(rockets_attendance, rockets)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)       Visitor/Neutral  PTS  \
# 0       8 2018-10-17 20:00:00+00:00      8:00p  New Orleans Pelicans  131
# 1      34 2018-10-20 22:30:00+00:00     10:30p       Houston Rockets  124
# 2      38 2018-10-21 21:00:00+00:00      9:00p       Houston Rockets  112
# 3      56 2018-10-24 20:00:00+00:00      8:00p             Utah Jazz  100
# 4      69 2018-10-26 20:00:00+00:00      8:00p  Los Angeles Clippers  133
# ..    ...                       ...        ...                   ...  ...
# 77   1162 2019-04-02 22:00:00+00:00     10:00p       Houston Rockets  130
# 78   1175 2019-04-03 22:30:00+00:00     10:30p       Houston Rockets  135
# 79   1182 2019-04-05 20:00:00+00:00      8:00p       New York Knicks   96
# 80   1200 2019-04-07 19:00:00+00:00      7:00p          Phoenix Suns  113
# 81   1217 2019-04-09 21:30:00+00:00      9:30p       Houston Rockets  111
#
#              Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0         Houston Rockets    112  Box Score        NaN    18055    NaN
# 1      Los Angeles Lakers    115  Box Score        NaN    18997    NaN
# 2    Los Angeles Clippers    115  Box Score        NaN    16149    NaN
# 3         Houston Rockets     89  Box Score        NaN    18055    NaN
# 4         Houston Rockets    113  Box Score        NaN    18055    NaN
# ..                    ...    ...        ...        ...      ...    ...
# 77       Sacramento Kings    105  Box Score        NaN    17583    NaN
# 78   Los Angeles Clippers    103  Box Score        NaN    17593    NaN
# 79        Houston Rockets    120  Box Score        NaN    18055    NaN
# 80        Houston Rockets    149  Box Score        NaN    18055    NaN
# 81  Oklahoma City Thunder    112  Box Score        NaN    18203    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      18055          1.000000                   0.467742
# 1      18997          1.000000                   0.600000
# 2      19068          0.846916                   0.549020
# 3      18055          1.000000                   0.348837
# 4      18055          1.000000                   0.400000
# ..       ...               ...                        ...
# 77     17583          1.000000                   0.610487
# 78     19068          0.922645                   0.544944
# 79     18055          1.000000                   0.629630
# 80     18055          1.000000                   0.579909
# 81     18203          1.000000                   0.597101
#
#     Positive Sentiment Ratio  Negative Sentiment Ratio
# 0                   0.209677                  0.258065
# 1                   0.100000                  0.500000
# 2                   0.039216                  0.509804
# 3                   0.116279                  0.232558
# 4                   0.266667                  0.133333
# ..                       ...                       ...
# 77                  0.157303                  0.453184
# 78                  0.117978                  0.426966
# 79                  0.170370                  0.459259
# 80                  0.191781                  0.388128
# 81                  0.171014                  0.426087
#
# [82 rows x 16 columns]

# %% [markdown]
# Warriors

# %%
neg_sentiment_ratio_calc(warriors_attendance, warriors)
# Out:
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\mitch\Anaconda3\envs\neuralnetworks\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     index                      Date Start (ET)        Visitor/Neutral  PTS  \
# 0       1 2018-10-16 22:30:00+00:00     10:30p  Oklahoma City Thunder  100
# 1      24 2018-10-19 22:30:00+00:00     10:30p  Golden State Warriors  124
# 2      37 2018-10-21 20:00:00+00:00      8:00p  Golden State Warriors   98
# 3      46 2018-10-22 22:30:00+00:00     10:30p           Phoenix Suns  103
# 4      61 2018-10-24 22:30:00+00:00     10:30p     Washington Wizards  122
# ..    ...                       ...        ...                    ...  ...
# 77   1178 2019-04-04 22:30:00+00:00     10:30p  Golden State Warriors  108
# 78   1190 2019-04-05 22:30:00+00:00     10:30p    Cleveland Cavaliers  114
# 79   1204 2019-04-07 20:30:00+00:00      8:30p   Los Angeles Clippers  104
# 80   1214 2019-04-09 20:00:00+00:00      8:00p  Golden State Warriors  112
# 81   1222 2019-04-10 20:00:00+00:00      8:00p  Golden State Warriors  117
#
#              Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  Notes  \
# 0   Golden State Warriors    108  Box Score        NaN    19596    NaN
# 1               Utah Jazz    123  Box Score        NaN    18306    NaN
# 2          Denver Nuggets    100  Box Score        NaN    19520    NaN
# 3   Golden State Warriors    123  Box Score        NaN    19596    NaN
# 4   Golden State Warriors    144  Box Score        NaN    19596    NaN
# ..                    ...    ...        ...        ...      ...    ...
# 77     Los Angeles Lakers     90  Box Score        NaN    18997    NaN
# 78  Golden State Warriors    120  Box Score        NaN    19596    NaN
# 79  Golden State Warriors    131  Box Score        NaN    19596    NaN
# 80   New Orleans Pelicans    103  Box Score        NaN    17090    NaN
# 81      Memphis Grizzlies    132  Box Score        NaN    17794    NaN
#
#     Capacity  Attendance Ratio  Polarized Sentiment Ratio  \
# 0      18064               1.0                   0.625641
# 1      18306               1.0                   0.662162
# 2      19520               1.0                   0.645161
# 3      18064               1.0                   0.571429
# 4      18064               1.0                   0.725000
# ..       ...               ...                        ...
# 77     18997               1.0                   0.722749
# 78     18064               1.0                   0.714976
# 79     18064               1.0                   0.654378
# 80     16867               1.0                   0.737143
# 81     17794               1.0                   0.673077
#
#     Positive Sentiment Ratio  Negative Sentiment Ratio
# 0                   0.266667                  0.358974
# 1                   0.229730                  0.432432
# 2                   0.193548                  0.451613
# 3                   0.171429                  0.400000
# 4                   0.325000                  0.400000
# ..                       ...                       ...
# 77                  0.191943                  0.530806
# 78                  0.202899                  0.512077
# 79                  0.253456                  0.400922
# 80                  0.228571                  0.508571
# 81                  0.230769                  0.442308
#
# [82 rows x 16 columns]

# %% [markdown]
# #### Plots

# %%
plt.subplots(2,3, figsize=(15,10))

plt.subplot(2,3,1)
plt.scatter(raptors_attendance['Negative Sentiment Ratio'], raptors_attendance['Attendance Ratio'])
plt.title('Raptors')

plt.subplot(2,3,2)
plt.scatter(knicks_attendance['Negative Sentiment Ratio'], knicks_attendance['Attendance Ratio'])
plt.title('Knicks')

plt.subplot(2,3,3)
plt.scatter(lakers_attendance['Negative Sentiment Ratio'], lakers_attendance['Attendance Ratio'])
plt.title('Lakers')

plt.subplot(2,3,4)
plt.scatter(rockets_attendance['Negative Sentiment Ratio'], rockets_attendance['Attendance Ratio'])
plt.title('Rockets')

plt.subplot(2,3,5)
plt.scatter(warriors_attendance['Negative Sentiment Ratio'], warriors_attendance['Attendance Ratio'])
plt.title('Warriors')

plt.show()

# %%
plt.subplots(2,3, figsize=(15,10))

plt.subplot(2,3,1)
plt.plot(raptors_attendance['Date'], raptors_attendance['Negative Sentiment Ratio'])
plt.title('Raptors')

plt.subplot(2,3,2)
plt.plot(knicks_attendance['Date'], knicks_attendance['Negative Sentiment Ratio'])
plt.title('Knicks')

plt.subplot(2,3,3)
plt.plot(lakers_attendance['Date'], lakers_attendance['Negative Sentiment Ratio'])
plt.title('Lakers')

plt.subplot(2,3,4)
plt.plot(rockets_attendance['Date'], rockets_attendance['Negative Sentiment Ratio'])
plt.title('Rockets')

plt.subplot(2,3,5)
plt.plot(warriors_attendance['Date'], warriors_attendance['Negative Sentiment Ratio'])
plt.title('Warriors')

plt.show()

# %%
plt.subplots(2,3, figsize=(20,10))

plt.subplot(2,3,1)
plt.plot(raptors_attendance['Date'], raptors_attendance['Attendance Ratio'], marker='.')
plt.title('Raptors')

plt.subplot(2,3,2)
plt.plot(knicks_attendance['Date'], knicks_attendance['Attendance Ratio'], marker='.')
plt.title('Knicks')

plt.subplot(2,3,3)
plt.plot(lakers_attendance['Date'], lakers_attendance['Attendance Ratio'], marker='.')
plt.title('Lakers')

plt.subplot(2,3,4)
plt.plot(rockets_attendance['Date'], rockets_attendance['Attendance Ratio'], marker='.')
plt.title('Rockets')

plt.subplot(2,3,5)
plt.plot(warriors_attendance['Date'], warriors_attendance['Attendance Ratio'], marker='.')
plt.title('Warriors')

plt.show()

# %% [markdown]
# #### Linear Regression Models

# %%
#function to run linear regression
def regression_modeler_neg_sent(attendance_df):
    X = attendance_df['Negative Sentiment Ratio']
    y = attendance_df['Attendance Ratio']
    
    X_withconstant = sm.add_constant(X)
    
    linreg = sm.OLS(y,X_withconstant)
    linreg_results = linreg.fit()
    return linreg_results.summary()

# %%
regression_modeler_neg_sent(raptors_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.185
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.280
# Time:                        12:59:55   Log-Likelihood:                 124.53
# No. Observations:                  82   AIC:                            -245.1
# Df Residuals:                      80   BIC:                            -240.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9619      0.016     60.337      0.000       0.930       0.994
# Negative Sentiment Ratio     0.0508      0.047      1.089      0.280      -0.042       0.144
# ==============================================================================
# Omnibus:                       51.335   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.489
# Skew:                          -2.324   Prob(JB):                     2.80e-29
# Kurtosis:                       7.109   Cond. No.                         8.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_neg_sent(knicks_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     2.384
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.127
# Time:                        12:59:55   Log-Likelihood:                 92.840
# No. Observations:                  82   AIC:                            -181.7
# Df Residuals:                      80   BIC:                            -176.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9003      0.029     31.076      0.000       0.843       0.958
# Negative Sentiment Ratio     0.1076      0.070      1.544      0.127      -0.031       0.246
# ==============================================================================
# Omnibus:                       40.072   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.814
# Skew:                          -1.877   Prob(JB):                     1.72e-18
# Kurtosis:                       6.140   Cond. No.                         9.27
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_neg_sent(lakers_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.1715
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.680
# Time:                        12:59:55   Log-Likelihood:                 254.11
# No. Observations:                  82   AIC:                            -504.2
# Df Residuals:                      80   BIC:                            -499.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9964      0.004    254.967      0.000       0.989       1.004
# Negative Sentiment Ratio     0.0039      0.010      0.414      0.680      -0.015       0.023
# ==============================================================================
# Omnibus:                      125.453   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3044.215
# Skew:                          -5.359   Prob(JB):                         0.00
# Kurtosis:                      30.859   Cond. No.                         9.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_neg_sent(rockets_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.09779
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.755
# Time:                        12:59:55   Log-Likelihood:                 115.72
# No. Observations:                  82   AIC:                            -227.4
# Df Residuals:                      80   BIC:                            -222.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9788      0.017     56.646      0.000       0.944       1.013
# Negative Sentiment Ratio    -0.0168      0.054     -0.313      0.755      -0.124       0.090
# ==============================================================================
# Omnibus:                       53.000   Durbin-Watson:                   2.281
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.220
# Skew:                          -2.338   Prob(JB):                     1.08e-32
# Kurtosis:                       7.607   Cond. No.                         8.88
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
regression_modeler_neg_sent(warriors_attendance)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Attendance Ratio   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.469
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):              0.229
# Time:                        12:59:55   Log-Likelihood:                 235.26
# No. Observations:                  82   AIC:                            -466.5
# Df Residuals:                      80   BIC:                            -461.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.9898      0.006    164.196      0.000       0.978       1.002
# Negative Sentiment Ratio     0.0203      0.017      1.212      0.229      -0.013       0.053
# ==============================================================================
# Omnibus:                      103.425   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1277.735
# Skew:                          -4.262   Prob(JB):                    3.50e-278
# Kurtosis:                      20.358   Cond. No.                         12.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Export Final CSVs for high quality visualization

# %%
raptors_attendance['At Home'] = raptors_attendance['Home/Neutral']
away = raptors_attendance['At Home'] != 'Toronto Raptors'
home = raptors_attendance['At Home'] == 'Toronto Raptors'
raptors_attendance['At Home'].where(away, 'Home', inplace = True)
raptors_attendance['At Home'].where(home, 'Away', inplace = True)

# %%
knicks_attendance['At Home'] = knicks_attendance['Home/Neutral']
away = knicks_attendance['At Home'] != 'New York Knicks'
home = knicks_attendance['At Home'] == 'New York Knicks'
knicks_attendance['At Home'].where(away, 'Home', inplace = True)
knicks_attendance['At Home'].where(home, 'Away', inplace = True)

# %%
lakers_attendance['At Home'] = lakers_attendance['Home/Neutral']
away = lakers_attendance['At Home'] != 'Los Angeles Lakers'
home = lakers_attendance['At Home'] == 'Los Angeles Lakers'
lakers_attendance['At Home'].where(away, 'Home', inplace = True)
lakers_attendance['At Home'].where(home, 'Away', inplace = True)

# %%
rockets_attendance['At Home'] = rockets_attendance['Home/Neutral']
away = rockets_attendance['At Home'] != 'Houston Rockets'
home = rockets_attendance['At Home'] == 'Houston Rockets'
rockets_attendance['At Home'].where(away, 'Home', inplace = True)
rockets_attendance['At Home'].where(home, 'Away', inplace = True)

# %%
warriors_attendance['At Home'] = warriors_attendance['Home/Neutral']
away = warriors_attendance['At Home'] != 'Golden State Warriors'
home = warriors_attendance['At Home'] == 'Golden State Warriors'
warriors_attendance['At Home'].where(away, 'Home', inplace = True)
warriors_attendance['At Home'].where(home, 'Away', inplace = True)

# %%
raptors_attendance.to_csv('data/raptors_results.csv')
knicks_attendance.to_csv('data/knicks_results.csv')
lakers_attendance.to_csv('data/lakers_results.csv')
rockets_attendance.to_csv('data/rockets_results.csv')
warriors_attendance.to_csv('data/warriors_results.csv')
